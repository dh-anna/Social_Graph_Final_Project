# %%
import plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Here are the hashes of the dataset files included in our analysis. Since IMDb datasets are updated daily, results may vary if the data is downloaded at a different time.

# %%
from dataset_hasher import hash_datasets

hash_datasets('../Datasets')
# Out:
# File #1
# --------------------------------------------------
#   Name:       .DS_Store
#   Path:       .DS_Store
#   Size:       8.00 KB (8,196 bytes)
#   Created:    2025-11-09 19:09:08
#   MD5 Hash:   1c0673a79355435a5694edeefe662abc
#
# File #2
# --------------------------------------------------
#   Name:       Celebrity.csv
#   Path:       Celebrity.csv
#   Size:       607.62 KB (622,202 bytes)
#   Created:    2024-07-31 15:41:24
#   MD5 Hash:   72884f07e61708a46305712ac4db2268
#
# File #3
# --------------------------------------------------
#   Name:       .DS_Store
#   Path:       IMDB/.DS_Store
#   Size:       6.00 KB (6,148 bytes)
#   Created:    2025-11-09 19:09:08
#   MD5 Hash:   fc5dd931a0057a788654c7e6265259bb
#
# File #4
# --------------------------------------------------
#   Name:       actorfilms.csv
#   Path:       IMDB/actorfilms.csv
#   Size:       11.96 MB (12,538,592 bytes)
#   Created:    2021-11-08 15:37:40
#   MD5 Hash:   5df9956f6c042db390f1b1484070e1f5
#
# File #5
# --------------------------------------------------
#   Name:       name.basics.tsv
#   Path:       IMDB/name.basics.tsv
#   Size:       874.45 MB (916,928,198 bytes)
#   Created:    2025-11-09 19:09:06
#   MD5 Hash:   f5471dae96edfb1d7f1347b9e23a104f
#
# File #6
# --------------------------------------------------
#   Name:       title.crew.tsv
#   Path:       IMDB/title.crew.tsv
#   Size:       378.85 MB (397,253,726 bytes)
#   Created:    2025-11-09 19:09:41
#   MD5 Hash:   fe13a1710cc90488a0be1b0ce149059f
#
# File #7
# --------------------------------------------------
#   Name:       IMDb movies.csv
#   Path:       IMDb movies.csv
#   Size:       45.62 MB (47,840,433 bytes)
#   Created:    2025-11-08 18:37:34
#   MD5 Hash:   93ff632f3331a4585962577991d4c8a9

# %%
import pandas as pd

df_actors = pd.read_csv('../Datasets/IMDB/actorfilms.csv', low_memory=False)
df_actors = df_actors[pd.to_numeric(df_actors['Year'], errors='coerce') >= 1980]

# %% [markdown]
# We took this dataset from IMDB. From this we can see in which films actors were in. We can see the actor's id, movie, the year that movie was released, the ratings and the filmid of the movie.

# %%
df_actors
# Out:
#                       Actor    ActorID                            Film  Year  \
# 39            Lauren Bacall  nm0000002              Ernest & Celestine  2012
# 40            Lauren Bacall  nm0000002                      The Forger  2012
# 41            Lauren Bacall  nm0000002                      All at Sea  2010
# 42            Lauren Bacall  nm0000002                      The Walker  2007
# 43            Lauren Bacall  nm0000002                       Manderlay  2005
# ...                     ...        ...                             ...   ...
# 191868  Roman Griffin Davis  nm9877392                     Jojo Rabbit  2019
# 191869            Lexi Rabe  nm9962642                       Silk Road  2021
# 191870            Lexi Rabe  nm9962642               Avengers: Endgame  2019
# 191871            Lexi Rabe  nm9962642  Godzilla: King of the Monsters  2019
# 191872      Inde Navarrette  nm9984699                   Wander Darkly  2020
#
#          Votes  Rating     FilmID
# 39       18793     7.9  tt1816518
# 40        4472     5.4  tt1368858
# 41         110     5.7  tt0858500
# 42        5256     5.8  tt0783608
# 43       22622     7.3  tt0342735
# ...        ...     ...        ...
# 191868  310904     7.9  tt2584384
# 191869    2050     5.9  tt7937254
# 191870  849079     8.4  tt4154796
# 191871  146737     6.0  tt3741700
# 191872     776     5.8  tt8902978
#
# [145601 rows x 7 columns]

# %%
actors_set = sorted(set(df_actors['Actor'].tolist()))  # Sorted for deterministic iteration

# %%
print("We have " +str(len(actors_set)) + " actors in the df_actors dataset.")
# Out:
# We have 9134 actors in the df_actors dataset.

# %% [markdown]
# We will cut out actors who had their first movies before 1980, because we wanted to work with more up-to-date actors.

# %%
from Actor_Director_Graph.actor_director_functions import cut_off_actors_whose_first_movie_was_before_1980

# cut out actors whose first film was before 1980

actors_after_1980 = cut_off_actors_whose_first_movie_was_before_1980(actors_set, df_actors)

# %%
#We will work with this many actors
print(f"We will only work with {len(actors_after_1980)} actors")
# Out:
# We will only work with 9134 actors

# %% [markdown]
# This dataframe contains IMDb ids of movie title's with director ids and writer ids. We will only work with the movies and directors from this df_movie_directors dataset.

# %%
df_movie_directors = pd.read_csv('../Datasets/IMDB/title.crew.tsv', sep='\t', low_memory=False)

# %%
df_movie_directors
# Out:
#              tconst   directors  \
# 0         tt0000001   nm0005690
# 1         tt0000002   nm0721526
# 2         tt0000003   nm0721526
# 3         tt0000004   nm0721526
# 4         tt0000005   nm0005690
# ...             ...         ...
# 12048914  tt9916848   nm1485677
# 12048915  tt9916850   nm1485677
# 12048916  tt9916852   nm1485677
# 12048917  tt9916856  nm10538645
# 12048918  tt9916880   nm0996406
#
#                                                     writers
# 0                                                        \N
# 1                                                        \N
# 2                                                 nm0721526
# 3                                                        \N
# 4                                                        \N
# ...                                                     ...
# 12048914  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 12048915            nm9187127,nm1485677,nm9826385,nm1628284
# 12048916  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 12048917                                          nm6951431
# 12048918                                nm1482639,nm2586970
#
# [12048919 rows x 3 columns]

# %% [markdown]
# This df_name_to_id dataset maps together people ids (e.g. directors, writers, actors) to their names.

# %%
df_name_to_id = pd.read_csv('../Datasets/IMDB/name.basics.tsv', sep='\t', low_memory=False)

# %%
df_name_to_id
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14859444  nm9993714   Romeo del Rosario        \N        \N
# 14859445  nm9993716       Essias Loberg        \N        \N
# 14859446  nm9993717  Harikrishnan Rajan        \N        \N
# 14859447  nm9993718         Aayush Nair        \N        \N
# 14859448  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1            actress,miscellaneous,soundtrack
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# 4                       writer,director,actor
# ...                                       ...
# 14859444  animation_department,art_department
# 14859445                                   \N
# 14859446                      cinematographer
# 14859447                      cinematographer
# 14859448                                   \N
#
#                                    knownForTitles
# 0         tt0072308,tt0050419,tt0027125,tt0025164
# 1         tt0037382,tt0075213,tt0038355,tt0117057
# 2         tt0057345,tt0049189,tt0056404,tt0054452
# 3         tt0072562,tt0077975,tt0080455,tt0078723
# 4         tt0050986,tt0069467,tt0083922,tt0050976
# ...                                           ...
# 14859444          tt11657662,tt14069590,tt2455546
# 14859445                                       \N
# 14859446                                tt8736744
# 14859447                                tt8736744
# 14859448                                       \N
#
# [14859449 rows x 6 columns]

# %% [markdown]
# We make a graph where actors and directors are nodes and there are directed links between actors to directors if they worked with them. The edge weight indicate how many times.

# %%
from Actor_Director_Graph.actor_director_functions import making_director_actor_graph
import pandas as pd

# Pre-compute lookups dictionary, because dataframes are slow
movie_directors_dict = df_movie_directors.set_index('tconst')['directors'].to_dict()
name_lookup = df_name_to_id.set_index('nconst')['primaryName'].to_dict()

# Filter actors data once and group by actor
actors_filtered = df_actors[df_actors['Actor'].isin(actors_after_1980)]
actors_grouped = actors_filtered.groupby('Actor')

# Initialize graph with all actors at once
actors_director_graph = making_director_actor_graph(actors_after_1980, actors_grouped,movie_directors_dict, name_lookup)

# %% [markdown]
# We take the largest component, so that we will only work with relevant actors who are not separated.

# %%
import networkx as nx
largest_cc_nodes = max(nx.connected_components(actors_director_graph.to_undirected()), key=len)
largest_cc_nodes = sorted(largest_cc_nodes)  # Sort for deterministic graph ordering
actors_director_graph = actors_director_graph.subgraph(largest_cc_nodes)

# %%
print(f"The actors-directors graph has {actors_director_graph.number_of_edges()} edges and {actors_director_graph.number_of_nodes()} nodes.")
# Out:
# The actors-directors graph has 149724 edges and 25358 nodes.

# %%
print(f"The largest component of the actors-directors graph has {actors_director_graph.number_of_edges()} edges and {actors_director_graph.number_of_nodes()} nodes.")
# Out:
# The largest component of the actors-directors graph has 149724 edges and 25358 nodes.

# %% [markdown]
# Here we collect the popular directors. As there are no datasets available with director popularity score, we took the IMDb movies.csv and calculate the popularity by summing the result of multiplying the rating of their movies and the number of rating. We explain the reasons in the report.

# %%
from Actor_Director_Graph.actor_director_functions import get_popular_directors


#We use the IMDb dataset and get rid of movies before 1980
df_movies_imdb = pd.read_csv('../Datasets/IMDb movies.csv', index_col=0, low_memory=False)
df_movies_imdb = df_movies_imdb[pd.to_numeric(df_movies_imdb['year'], errors='coerce') >= 1980]

# Sort by average popularity
director_stats_sorted = get_popular_directors(df_movies_imdb)

# %% [markdown]
# We can see that there are indeed popular directors at the beginning of the list

# %%
director_stats_sorted
# Out:
#                 director  total_popularity  num_movies
# 4911   Christopher Nolan        99486881.7          11
# 21629  Quentin Tarantino        75651625.0          12
# 25560   Steven Spielberg        64856945.6          20
# 21042      Peter Jackson        60483109.9          11
# 6127       David Fincher        56634054.9          10
# ...                  ...               ...         ...
# 27983      Waleed Bedour             139.2           1
# 18524    Michele Lunella             138.6           1
# 12405      Jianrong Zhuo             133.1           1
# 388     Aeneas Middleton             128.7           1
# 21936  Ramana Reddy B.V.             107.0           1
#
# [29023 rows x 3 columns]

# %% [markdown]
# We check the total_popularity of directors and observe a clear drop around ranks 200–300. Therefore, we select 400 as a slightly higher cutoff to avoid excluding directors who are still meaningfully popular.

# %%
import pandas as pd
import matplotlib.pyplot as plt
values = director_stats_sorted['total_popularity'].values

plt.plot(values[:int((len(director_stats_sorted)*0.05))])
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Here we performed community detection with the Louvain-algorithm.

# %%
from Actor_Director_Graph.actor_director_functions import make_louvain_communities
import networkx as nx

cluster_labels,nodes, embeddings = make_louvain_communities(actors_director_graph, actors_director_graph)
# Out:
# Louvain detected 30 communities
# The modularity: 0.4078
# Number of communities detected: 30
#
# Community sizes:
#   Community 0: 5525 members
#   Community 1: 4321 members
#   Community 2: 3784 members
#   Community 3: 3497 members
#   Community 4: 2338 members
#   Community 5: 1085 members
#   Community 6: 781 members
#   Community 7: 705 members
#   Community 8: 693 members
#   Community 9: 547 members

# %%
from Actor_Director_Graph.cluster_naming_llm import generate_name_for_clusters
from dotenv import load_dotenv
load_dotenv()   #Load the .env file containing the API key for the LLM

cluster_names = generate_name_for_clusters(nodes, cluster_labels, cache_path="cluster_names.json", max_names_per_cluster=100_000)
print(f"Name for cluster 0: {cluster_names[0]}")
# Out:
# Loaded 30 cluster names from cache: cluster_names.json
# Name for cluster 0: Mixed B-Movie and Independent Film Actors

# %% [markdown]
# The next cell is needed for creating a 3D visualization of the graph: https://dh-anna.github.io/Social_Graph_Final_Project/
# It only exports the graph in a gziped JSON format that is readable by our visualizer.

# %%
import json
import gzip

# Filter to most important nodes/edges
degree_dict = dict(actors_director_graph.degree())
top_nodes = sorted(degree_dict, key=degree_dict.get, reverse=True)[:1000]
subgraph = actors_director_graph.subgraph(top_nodes).copy()

# Create node to cluster mapping from Louvain results
node_to_cluster = {node: int(cluster) for node, cluster in zip(nodes, cluster_labels)}

# Determine node type based on graph structure and add cluster data:
# In this directed graph, edges go from actor -> director
# So: nodes with incoming edges are directors, nodes with only outgoing edges are actors
for node in subgraph.nodes():
    in_degree = subgraph.in_degree(node)
    out_degree = subgraph.out_degree(node)

    if in_degree > 0 and out_degree == 0:
        # Only receives edges = pure director
        subgraph.nodes[node]['type'] = 'director'
    elif in_degree == 0 and out_degree > 0:
        # Only sends edges = pure actor
        subgraph.nodes[node]['type'] = 'actor'
    elif in_degree > 0 and out_degree > 0:
        # Both = actor-director (classify based on which role dominates)
        # If more incoming than outgoing, they're primarily a director
        subgraph.nodes[node]['type'] = 'director' if in_degree >= out_degree else 'actor'
    else:
        # Isolated node (shouldn't happen in largest component)
        subgraph.nodes[node]['type'] = 'unknown'

    # Add cluster data
    if node in node_to_cluster:
        subgraph.nodes[node]['cluster'] = node_to_cluster[node]
    else:
        subgraph.nodes[node]['cluster'] = -1  # Unknown cluster

data = nx.node_link_data(subgraph, edges="links")
with gzip.open('../3d-visualization/public/graph.json.gz', 'wt') as f:
    json.dump(data, f, separators=(',', ':'))

# %% [markdown]
# Here we print some of the members from each community.

# %%
from Actor_Director_Graph.actor_director_functions import clusters_to_node, print_members_for_each_clusters

# Create a dictionary mapping cluster to nodes
cluster_to_nodes = clusters_to_node(nodes, cluster_labels)
# Print members of each cluster
print_members_for_each_clusters(cluster_to_nodes)
# Out:
# Cluster 0 (5525 members):
# A Martinez, A. Blaine Miller, A. Dean Bell, A. Raven Cruz, A. Todd Smith, A.J. Briones, A.J. Mattioli, AJ Michalka, Aaliyah, Aaron Ashmore
# ... and 5515 more
#
# Cluster 1 (4321 members):
# A.D. Calvo, A.J. Bond, A.J. Cook, A.J. Kparr, A.T. White, Aaron Blaise, Aaron Fjellman, Aaron Fradkin, Aaron Harvey, Aaron Katz
# ... and 4311 more
#
# Cluster 2 (3784 members):
# 50 Cent, A.J. Edwards, A.J. Langer, A.W. Vidmer, Aaron B. Koontz, Aaron Douglas, Aaron Eckhart, Aaron Fisher, Aaron J. Wiederspahn, Aaron Rottinghaus
# ... and 3774 more
#
# Cluster 3 (3497 members):
# Aadila Dosani, Aaron McCann, Aaron Paul, Aaron Taylor-Johnson, Aash Aaron, Abdul Latif Salazar, Abigail Blackmore, Abner Pastoll, Ace Bhatti, Ada Nicodemou
# ... and 3487 more
#
# Cluster 4 (2338 members):
# Abbas Fahdel, Abbas Kiarostami, Abdellatif Kechiche, Abderrahmane Sissako, Abril Zamora, Achero Mañas, Achim von Borries, Adam Bogen, Adam MacDonald, Adele Exarchopoulos
# ... and 2328 more
#
# Cluster 5 (1085 members):
# A.J. Buckley, Aaron Horvath, Abe Vigoda, Abhiraj Minawala, Adam Croasdell, Adam Fields, Adam Weissman, Adam Wylie, Adrian Molina, Akie Ishii
# ... and 1075 more
#
# Cluster 6 (781 members):
# Aaron Jeffery, Aaron Pedersen, Aaron Warwick, Abbey Lee, Abbie Cornish, Abe Forsythe, Adam Robitel, Aden Young, Adria Arjona, Aisling Franciosi
# ... and 771 more
#
# Cluster 7 (705 members):
# A. Sayeeda Moreno, A.M. Lukas, Aaron Soto, Abby Kohn, Abe Sylvia, Acán Coen, Adam Egypt Mortimer, Adam Horton, Adam Leon, Adam Wingard
# ... and 695 more
#
# Cluster 8 (693 members):
# A. Jagadesh, A. Karunakaran, A. Kodandarami Reddy, A. Mahadev, A.K. Sajan, A.L. Vijay, A.R. Gandhi Krishna, A.R. Murugadoss, Aamir Khan, Aanand L. Rai
# ... and 683 more
#
# Cluster 9 (547 members):
# Aaron Moorhead, Aditya Pawar, Adrian Tudor, Akira Akbar, Alan Dale, Alan Ferguson, Alex Goldberg, Alexander Røsler, Ali Cobrin, Alison Becker
# ... and 537 more
#
# Cluster 10 (521 members):
# Aage Rais-Nordentoft, Agneta Fagerström-Olsson, Ahmed Imamovic, Aku Louhimies, Aleksandar Popovski, Aleksi Mäkelä, Aleksi Salmenperä, Alex Hogh Andersen, Alexander Brøndsted, Alexander Skarsgard
# ... and 511 more
#
# Cluster 11 (346 members):
# Alan Lindsay, Alan Mak, Alan Yuen, Alex Law, Alexi Tan, Alfred Cheung, Aman Chang, Ami Canaan Mann, Ande Luo, Andrew Repasky McElhinney
# ... and 336 more
#
# Cluster 12 (311 members):
# Aaron Lohr, Abigail Spencer, Adam Kaufman, Adam Linzey, Ahna O'Reilly, Alana Waksman, Albert Hanan Kaminski, Alexis Gambis, Allen Wolf, Alyshia Ochse
# ... and 301 more
#
# Cluster 13 (274 members):
# Ahn Sang-hoon, Alan S. Kim, Aliakbar Campwala, Anderson Matthew, Bae Doona, Bae Suzy, Benson Lee, Bong Joon Ho, Boots Riley, Bruce Parramore
# ... and 264 more
#
# Cluster 14 (154 members):
# Aaron Leong, Aaron Moles, Adam Ganzer, Alex Kavutskiy, Alexander Emmert, Alexandria DeBerry, Andy Signore, Antoni McVay, Ariel Gardner, Austin Salmi
# ... and 144 more
#
# Cluster 15 (134 members):
# Aimee Lagos, Alec Sokolow, Alfons Adetuyi, Andrea Londo, Andrew Nackman, Anthony Cousins, Antoni Ribas, Ashley Greene, Baron Vaughn, Barry Alexander Brown
# ... and 124 more
#
# Cluster 16 (130 members):
# Aaron Fronk, Abby Miller, Alessandro Siani, Ali Paras, Andrew T. Wright, Andrew Wesman, Andromeda Godfrey, Anil Rao, Anisa Qureshi, Anthony Lund
# ... and 120 more
#
# Cluster 17 (86 members):
# Abbie Cobb, Abigail Cowen, Agusta Eva Erlendsdottir, Al Corley, Alexis Wajsbrot, Andrew Erwin, Barbara Feldon, Bella Dayne, Ben Browder, Bess Armstrong
# ... and 76 more
#
# Cluster 18 (39 members):
# A. Taner Elhan, Ali Bilgin, Ali Özgentürk, Alper Mestçi, Aras Bulut Iynemli, Biray Dalkiran, Burak Ozcivit, Cagatay Ulusoy, Cem Yilmaz, Deniz Denizciler
# ... and 29 more
#
# Cluster 19 (33 members):
# Alek Keshishian, Alessandra Ambrosio, Alex Munoz, Amber Valletta, Ben Mor, Bruno Ilogti, Celia Fox, Chris Marrs Piliero, Chris Ullens, Chrissy Teigen
# ... and 23 more
#
# Cluster 20 (14 members):
# Attila Janisch, Attila Mispál, Csaba Fazekas, Emil Novák, Gyula Nemes, Géza Bereményi, József Sipos, Mari Torocsik, Márta Mészáros, Pál Sándor
# ... and 4 more
#
# Cluster 21 (12 members):
# Ali Yorgancioglu, Appie Boudellah, Aram van de Rest, Erwin van den Eshof, Lodewijk van Lelyveld, Martijn Smits, Matthias Temmermans, Pim van Hoeve, Remy van Heugten, Robert A. Jansen
# ... and 2 more
#
# Cluster 22 (5 members):
# Jason Woliner, Kristina Grozeva, Magdalena Ralcheva, Maria Bakalova, Petar Valchanov
#
# Cluster 23 (4 members):
# FINT, Kiki Sukezane, Shigeaki Kubo, Tsuyoshi Nakakuki
#
# Cluster 24 (4 members):
# Helena Zengel, Leonie Krippendorff, Mascha Schilinski, Nora Fingscheidt
#
# Cluster 25 (3 members):
# Fredrik Hiller, Hafthor Julius Bjornsson, Raouf Abdul Aziz
#
# Cluster 26 (3 members):
# Calvin Aurand, Harry Styles, Paul Dugdale
#
# Cluster 27 (3 members):
# Kimani Ray Smith, Kristy Dawn Dinsmore, Laci J Mailey
#
# Cluster 28 (3 members):
# Amar Adatia, Peter Peralta, Rahul Kohli
#
# Cluster 29 (3 members):
# Butch Patrick, Daniel Erickson, William Winckler

# %%
import statistics

def cluster_statistics(cluster_to_nodes):

    num_clusters = len(cluster_to_nodes)

    cluster_sizes = [len(nodes) for nodes in cluster_to_nodes.values()]

    total_nodes = sum(cluster_sizes)

    min_size = min(cluster_sizes)
    max_size = max(cluster_sizes)
    mean_size = statistics.mean(cluster_sizes)
    median_size = statistics.median(cluster_sizes)
    stdev_size = statistics.stdev(cluster_sizes) if len(cluster_sizes) > 1 else 0

    print(f"Number of clusters: {num_clusters}")
    print(f"Total nodes: {total_nodes}")
    print(f"\nCluster size statistics:")
    print(f"  Min:    {min_size}")
    print(f"  Max:    {max_size}")
    print(f"  Mean:   {mean_size:.2f}")
    print(f"  Median: {median_size}")
    print(f"  Stdev:  {stdev_size:.2f}")

    # Size distribution (histogram buckets)
    print(f"\nSize distribution:")
    size_counts = {}
    for size in cluster_sizes:
        size_counts[size] = size_counts.get(size, 0) + 1
    for size in sorted(size_counts.keys()):
        print(f"  Size {size}: {size_counts[size]} cluster(s)")



cluster_statistics(cluster_to_nodes)
# Out:
# Number of clusters: 30
# Total nodes: 25358
#
# Cluster size statistics:
#   Min:    3
#   Max:    5525
#   Mean:   845.27
#   Median: 144.0
#   Stdev:  1479.42
#
# Size distribution:
#   Size 3: 5 cluster(s)
#   Size 4: 2 cluster(s)
#   Size 5: 1 cluster(s)
#   Size 12: 1 cluster(s)
#   Size 14: 1 cluster(s)
#   Size 33: 1 cluster(s)
#   Size 39: 1 cluster(s)
#   Size 86: 1 cluster(s)
#   Size 130: 1 cluster(s)
#   Size 134: 1 cluster(s)
#   Size 154: 1 cluster(s)
#   Size 274: 1 cluster(s)
#   Size 311: 1 cluster(s)
#   Size 346: 1 cluster(s)
#   Size 521: 1 cluster(s)
#   Size 547: 1 cluster(s)
#   Size 693: 1 cluster(s)
#   Size 705: 1 cluster(s)
#   Size 781: 1 cluster(s)
#   Size 1085: 1 cluster(s)
#   Size 2338: 1 cluster(s)
#   Size 3497: 1 cluster(s)
#   Size 3784: 1 cluster(s)
#   Size 4321: 1 cluster(s)
#   Size 5525: 1 cluster(s)

# %% [markdown]
# Here we list some basic statistics about the clusters

# %% [markdown]
# We can see that the nodes with the biggest degree centrality are all established directors.

# %%
# Get degree centrality for filtered graph
degree_centrality = nx.degree_centrality(actors_director_graph)
sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True)[:10]
# Out:
# [('Woody Allen', 0.01372402098039989),
#  ('Steven Spielberg', 0.012619789407264267),
#  ('Clint Eastwood', 0.010805694679970028),
#  ('Steven Soderbergh', 0.010687384154276926),
#  ('Michael Bay', 0.009780336790629807),
#  ('Ridley Scott', 0.009701463106834405),
#  ('Oliver Stone', 0.009307094687857396),
#  ('Ron Howard', 0.00855779469180108),
#  ('Eric Roberts', 0.008281736798517176),
#  ('James Franco', 0.008281736798517176)]

# %% [markdown]
# For each cluster whe print out the members who have the highest node centrality.

# %%
from Actor_Director_Graph.actor_director_functions import find_top_n_members_of_each_cluster

# Find top n members by centrality in each cluster, this is just interesting fact
find_top_n_members_of_each_cluster(5, cluster_to_nodes,degree_centrality, actors_director_graph )
# Out:
# Cluster 0 - Top 5 most connected:
#   Ron Howard (degree: 217)
#   Eric Roberts (degree: 210)
#   Robert Rodriguez (degree: 208)
#   Quentin Tarantino (degree: 207)
#   Danny Trejo (degree: 175)
#
# Cluster 1 - Top 5 most connected:
#   Woody Allen (degree: 348)
#   Brett Ratner (degree: 208)
#   Peter Farrelly (degree: 195)
#   Garry Marshall (degree: 191)
#   Steven Brill (degree: 185)
#
# Cluster 2 - Top 5 most connected:
#   Steven Spielberg (degree: 320)
#   Clint Eastwood (degree: 274)
#   Steven Soderbergh (degree: 271)
#   Michael Bay (degree: 248)
#   Oliver Stone (degree: 236)
#
# Cluster 3 - Top 5 most connected:
#   Ridley Scott (degree: 246)
#   Chris Columbus (degree: 190)
#   Tim Burton (degree: 179)
#   J.J. Abrams (degree: 164)
#   Kenneth Branagh (degree: 164)
#
# Cluster 4 - Top 5 most connected:
#   Gerard Depardieu (degree: 118)
#   Neil Jordan (degree: 118)
#   Liam Neeson (degree: 115)
#   David Cronenberg (degree: 113)
#   Udo Kier (degree: 108)
#
# Cluster 5 - Top 5 most connected:
#   Frank Welker (degree: 110)
#   Fred Tatasciore (degree: 101)
#   Yuri Lowenthal (degree: 81)
#   Andrew Stanton (degree: 79)
#   Jim Cummings (degree: 79)
#
# Cluster 6 - Top 5 most connected:
#   Zack Snyder (degree: 122)
#   David Ayer (degree: 97)
#   George Miller (degree: 83)
#   James Wan (degree: 83)
#   Anthony LaPaglia (degree: 68)
#
# Cluster 7 - Top 5 most connected:
#   Kevin Smith (degree: 157)
#   Adam Wingard (degree: 92)
#   David Leitch (degree: 74)
#   Larry Fessenden (degree: 74)
#   Neil Maskell (degree: 68)
#
# Cluster 8 - Top 5 most connected:
#   Anupam Kher (degree: 167)
#   Amitabh Bachchan (degree: 93)
#   Akshay Kumar (degree: 92)
#   Irrfan Khan (degree: 79)
#   Salman Khan (degree: 74)
#
# Cluster 9 - Top 5 most connected:
#   Jon Favreau (degree: 141)
#   Joe Russo (degree: 135)
#   Anthony Russo (degree: 131)
#   Tyler Perry (degree: 117)
#   Rob Cohen (degree: 95)
#
# Cluster 10 - Top 5 most connected:
#   Stellan Skarsgard (degree: 69)
#   Rade Serbedzija (degree: 63)
#   Susanne Bier (degree: 55)
#   Michael Nyqvist (degree: 48)
#   Ulrich Thomsen (degree: 42)
#
# Cluster 11 - Top 5 most connected:
#   David Lynch (degree: 103)
#   Qi Shu (degree: 77)
#   Jackie Chan (degree: 66)
#   Joan Chen (degree: 56)
#   Donnie Yen (degree: 55)
#
# Cluster 12 - Top 5 most connected:
#   James Franco (degree: 210)
#   Sam Raimi (degree: 116)
#   Martin Sheen (degree: 86)
#   Beth Grant (degree: 84)
#   Matthew Modine (degree: 73)
#
# Cluster 13 - Top 5 most connected:
#   Ma Dong-seok (degree: 42)
#   Lee Byung-Hun (degree: 35)
#   Bong Joon Ho (degree: 28)
#   Kim Jee-woon (degree: 26)
#   Izabella Miko (degree: 23)
#
# Cluster 14 - Top 5 most connected:
#   Dawna Lee Heising (degree: 74)
#   Colton Dunn (degree: 69)
#   Stephanie Allynne (degree: 68)
#   Eugene Cordero (degree: 67)
#   P.J. Soles (degree: 55)
#
# Cluster 15 - Top 5 most connected:
#   Bill Condon (degree: 128)
#   Catherine Hardwicke (degree: 90)
#   Graham Greene (degree: 56)
#   Peter Facinelli (degree: 48)
#   David Slade (degree: 43)
#
# Cluster 16 - Top 5 most connected:
#   Natalia Tena (degree: 63)
#   Hermione Corfield (degree: 58)
#   Stuart Martin (degree: 51)
#   Tracie Thoms (degree: 50)
#   Lance Reddick (degree: 45)
#
# Cluster 17 - Top 5 most connected:
#   Sean Astin (degree: 68)
#   Andrew Erwin (degree: 26)
#   Jon Erwin (degree: 26)
#   Olafur Darri Olafsson (degree: 24)
#   Ben Browder (degree: 21)
#
# Cluster 18 - Top 5 most connected:
#   Engin Altan Duzyatan (degree: 11)
#   Tuvana Turkay (degree: 10)
#   Burak Ozcivit (degree: 6)
#   Cagatay Ulusoy (degree: 4)
#   Engin Akyurek (degree: 4)
#
# Cluster 19 - Top 5 most connected:
#   Jonas Åkerlund (degree: 58)
#   Jay Hernandez (degree: 39)
#   Wilmer Valderrama (degree: 32)
#   Alek Keshishian (degree: 28)
#   Amber Valletta (degree: 28)
#
# Cluster 20 - Top 5 most connected:
#   Mari Torocsik (degree: 16)
#   Attila Janisch (degree: 1)
#   Attila Mispál (degree: 1)
#   Csaba Fazekas (degree: 1)
#   Emil Novák (degree: 1)
#
# Cluster 21 - Top 5 most connected:
#   Yolanthe Cabau (degree: 13)
#   Ali Yorgancioglu (degree: 1)
#   Appie Boudellah (degree: 1)
#   Aram van de Rest (degree: 1)
#   Erwin van den Eshof (degree: 1)
#
# Cluster 22 - Top 5 most connected:
#   Maria Bakalova (degree: 4)
#   Jason Woliner (degree: 3)
#   Kristina Grozeva (degree: 1)
#   Magdalena Ralcheva (degree: 1)
#   Petar Valchanov (degree: 1)
#
# Cluster 23 - Top 5 most connected:
#   Kiki Sukezane (degree: 4)
#   FINT (degree: 1)
#   Shigeaki Kubo (degree: 1)
#   Tsuyoshi Nakakuki (degree: 1)
#
# Cluster 24 - Top 5 most connected:
#   Helena Zengel (degree: 4)
#   Leonie Krippendorff (degree: 1)
#   Mascha Schilinski (degree: 1)
#   Nora Fingscheidt (degree: 1)
#
# Cluster 25 - Top 5 most connected:
#   Hafthor Julius Bjornsson (degree: 3)
#   Fredrik Hiller (degree: 1)
#   Raouf Abdul Aziz (degree: 1)
#
# Cluster 26 - Top 5 most connected:
#   Harry Styles (degree: 3)
#   Calvin Aurand (degree: 1)
#   Paul Dugdale (degree: 1)
#
# Cluster 27 - Top 5 most connected:
#   Kimani Ray Smith (degree: 3)
#   Laci J Mailey (degree: 2)
#   Kristy Dawn Dinsmore (degree: 1)
#
# Cluster 28 - Top 5 most connected:
#   Rahul Kohli (degree: 3)
#   Amar Adatia (degree: 1)
#   Peter Peralta (degree: 1)
#
# Cluster 29 - Top 5 most connected:
#   Butch Patrick (degree: 3)
#   Daniel Erickson (degree: 2)
#   William Winckler (degree: 1)

# %% [markdown]
# Now we analyze which cluster contains directors with the highest node centrality.

# %%
from Actor_Director_Graph.actor_director_functions import calculate_member_centralities, \
    find_cluster_with_highest_avg_centrality

cluster_centralities = calculate_member_centralities(cluster_to_nodes, degree_centrality)

sorted_by_average_centrality = sorted( cluster_centralities.items(), key=lambda x: x[1]['avg_centrality'], reverse=True)

for rank, (cluster_id, data) in enumerate(sorted_by_average_centrality[:10], 1):
    print(f"\n{rank}. Cluster {cluster_id}:")
    print(f"   Avg centrality: {data['avg_centrality']:.6f}")
    print(f"   Size: {data['size']} members")


members_with_centrality = find_cluster_with_highest_avg_centrality(sorted_by_average_centrality, degree_centrality, actors_director_graph)
# Out:
# 1. Cluster 2:
#    Avg centrality: 0.000730
#    Size: 3784 members
#
# 2. Cluster 1:
#    Avg centrality: 0.000689
#    Size: 4321 members
#
# 3. Cluster 3:
#    Avg centrality: 0.000520
#    Size: 3497 members
#
# 4. Cluster 19:
#    Avg centrality: 0.000516
#    Size: 33 members
#
# 5. Cluster 12:
#    Avg centrality: 0.000434
#    Size: 311 members
#
# 6. Cluster 5:
#    Avg centrality: 0.000426
#    Size: 1085 members
#
# 7. Cluster 15:
#    Avg centrality: 0.000403
#    Size: 134 members
#
# 8. Cluster 9:
#    Avg centrality: 0.000399
#    Size: 547 members
#
# 9. Cluster 6:
#    Avg centrality: 0.000351
#    Size: 781 members
#
# 10. Cluster 0:
#    Avg centrality: 0.000343
#    Size: 5525 members
#
# Cluster 2 has the highest average centrality of 0.000730
# Rank   Director or Actor                        Centrality      Degree
# 1      Steven Spielberg                         0.012620        320
# 2      Clint Eastwood                           0.010806        274
# 3      Steven Soderbergh                        0.010687        271
# 4      Michael Bay                              0.009780        248
# 5      Oliver Stone                             0.009307        236
# 6      Martin Scorsese                          0.007887        200
# 7      Roland Emmerich                          0.007887        200
# 8      Spike Lee                                0.007808        198
# 9      Barry Levinson                           0.006941        176
# 10     Joel Schumacher                          0.006862        174
# 11     Ethan Coen                               0.006783        172
# 12     Joel Coen                                0.006783        172
# 13     Tony Scott                               0.006586        167
# 14     Wes Craven                               0.006389        162
# 15     Robert Altman                            0.006034        153
# 16     David Fincher                            0.005916        150
# 17     Gus Van Sant                             0.005679        144
# 18     Antoine Fuqua                            0.005600        142
# 19     Lasse Hallström                          0.005561        141
# 20     Robert Zemeckis                          0.005561        141

# %%
from Actor_Director_Graph.actor_director_functions import visualize_actor_director_graph

visualize_actor_director_graph(embeddings,cluster_labels, nodes )

# %% [markdown]
# We can also find people in the clusters with this function

# %%
from Actor_Director_Graph.actor_director_functions import find_person_cluster

# Find which cluster contains specific actors/directors

# Example usage
find_person_cluster("Lionel Barrymore", nodes, cluster_labels, cluster_to_nodes)
find_person_cluster("Tom Hanks", nodes, cluster_labels, cluster_to_nodes)
# Out:
# Lionel Barrymore not found (might have been filtered out)
# Tom Hanks is in Cluster 2
# Other members include: 50 Cent, A.J. Edwards, A.J. Langer, A.W. Vidmer, Aaron B. Koontz...

# %% [markdown]
# This is needed because we first used another director_popularity dataset, but it turned out to be not so good. After that we created the director_stats_sorted, but by that time we already used the term director_popularity everwhere and we did not want to change it.

# %%
director_popularity = director_stats_sorted

# %% [markdown]
# First we wanted to select the first few percentage of the directors as the "most popular directors". We made a cutoff for popular director at 400 as we discussed above.

# %%
from Actor_Director_Graph.actor_director_functions import calculate_popular_directors_for_each_cluster, print_popular_directors_in_each_cluster

# We find the most popular directors
n_popular = 400
popularity_threshold = director_popularity['total_popularity'].nlargest(n_popular).min()  #.quantile(0.75)
popular_directors = set(director_popularity[director_popularity['total_popularity'] >= popularity_threshold]['director'])


print(f"We select the first {len(popular_directors)} directors as popular directors. \n")

# Count popular directors in each cluster
cluster_popular_counts, cluster_popular_directors = calculate_popular_directors_for_each_cluster(cluster_to_nodes,popular_directors)

cluster_popular_directors_percentages= print_popular_directors_in_each_cluster(cluster_popular_counts, cluster_popular_directors, cluster_to_nodes)
# Out:
# We select the first 400 directors as popular directors.
#
# Cluster 0: 16 popular directors out of 5525 total members (0.3%)
#   Examples: Brian Taylor, Darren Lynn Bousman, Eli Roth, Eric Bress, Frank Miller
#
# Cluster 1: 117 popular directors out of 4321 total members (2.7%)
#   Examples: Adam McKay, Adam Shankman, Andy Tennant, Ang Lee, Anne Fletcher
#
# Cluster 2: 96 popular directors out of 3784 total members (2.5%)
#   Examples: Alexander Payne, Allen Hughes, Andrew Davis, Andrew Niccol, Antoine Fuqua
#
# Cluster 3: 89 popular directors out of 3497 total members (2.5%)
#   Examples: Alan Taylor, Albert Hughes, Alejandro Amenábar, Alex Garland, Alexandre Aja
#
# Cluster 4: 13 popular directors out of 2338 total members (0.6%)
#   Examples: Alejandro G. Iñárritu, Andy Muschietti, Asghar Farhadi, David Cronenberg, J.A. Bayona
#
# Cluster 5: 21 popular directors out of 1085 total members (1.9%)
#   Examples: Adrian Molina, Andrew Stanton, Ash Brannon, Bob Peterson, Brad Bird
#
# Cluster 6: 15 popular directors out of 781 total members (1.9%)
#   Examples: Alex Proyas, Baz Luhrmann, David Ayer, David F. Sandberg, Derek Cianfrance
#
# Cluster 7: 2 popular directors out of 705 total members (0.3%)
#   Examples: David Leitch, Kevin Smith
#
# Cluster 8: 1 popular directors out of 693 total members (0.1%)
#   Examples: Rajkumar Hirani
#
# Cluster 9: 15 popular directors out of 547 total members (2.7%)
#   Examples: Anna Boden, Anthony Russo, Don Hall, Drew Goddard, Joe Russo
#
# Cluster 10: 3 popular directors out of 521 total members (0.6%)
#   Examples: Nicolas Winding Refn, Susanne Bier, Thomas Vinterberg
#
# Cluster 11: 2 popular directors out of 346 total members (0.6%)
#   Examples: David Lynch, Wilson Yip
#
# Cluster 12: 2 popular directors out of 311 total members (0.6%)
#   Examples: Fede Alvarez, Sam Raimi
#
# Cluster 13: 2 popular directors out of 274 total members (0.7%)
#   Examples: Bong Joon Ho, Chan-wook Park
#
# Cluster 14: 0 popular directors out of 154 total members (0.0%)
#
# Cluster 15: 3 popular directors out of 134 total members (2.2%)
#   Examples: Bill Condon, Catherine Hardwicke, David Slade
#
# Cluster 16: 0 popular directors out of 130 total members (0.0%)
#
# Cluster 17: 0 popular directors out of 86 total members (0.0%)
#
# Cluster 18: 0 popular directors out of 39 total members (0.0%)
#
# Cluster 19: 0 popular directors out of 33 total members (0.0%)
#
# Cluster 20: 0 popular directors out of 14 total members (0.0%)
#
# Cluster 21: 0 popular directors out of 12 total members (0.0%)
#
# Cluster 22: 0 popular directors out of 5 total members (0.0%)
#
# Cluster 23: 0 popular directors out of 4 total members (0.0%)
#
# Cluster 24: 0 popular directors out of 4 total members (0.0%)
#
# Cluster 25: 0 popular directors out of 3 total members (0.0%)
#
# Cluster 26: 0 popular directors out of 3 total members (0.0%)
#
# Cluster 27: 0 popular directors out of 3 total members (0.0%)
#
# Cluster 28: 0 popular directors out of 3 total members (0.0%)
#
# Cluster 29: 0 popular directors out of 3 total members (0.0%)

# %%
cluster_popular_directors_percentages
# Out:
# {0: 0.28959276018099545,
#  1: 2.707706549409859,
#  2: 2.536997885835095,
#  3: 2.545038604518158,
#  4: 0.5560307955517536,
#  5: 1.935483870967742,
#  6: 1.9206145966709345,
#  7: 0.28368794326241137,
#  8: 0.1443001443001443,
#  9: 2.742230347349177,
#  10: 0.5758157389635317,
#  11: 0.5780346820809248,
#  12: 0.6430868167202572,
#  13: 0.7299270072992701,
#  14: 0.0,
#  15: 2.2388059701492535,
#  16: 0.0,
#  17: 0.0,
#  18: 0.0,
#  19: 0.0,
#  20: 0.0,
#  21: 0.0,
#  22: 0.0,
#  23: 0.0,
#  24: 0.0,
#  25: 0.0,
#  26: 0.0,
#  27: 0.0,
#  28: 0.0,
#  29: 0.0}

# %%
from Actor_Director_Graph.actor_director_functions import check_how_many_popular_directors_in_the_graph

# Check how many popular directors are actually in the graph nodes
check_how_many_popular_directors_in_the_graph(director_popularity, nodes)
# Out:
#   Found in graph: 15337
#   NOT found in graph: 13686
#
# Popular directors IN the graph:
#   - Christopher Nolan
#   - Quentin Tarantino
#   - Steven Spielberg
#   - Peter Jackson
#   - David Fincher
#   - Martin Scorsese
#   - Ridley Scott
#   - Frank Darabont
#   - Robert Zemeckis
#   - Clint Eastwood
#
# Popular directors NOT in the graph (name mismatch or filtered out):
#   - Mike Thurmeier
#   - Kar-Wai Wong
#   - Jee-woon Kim
#   - Ki-duk Kim
#   - Andrew Lau
#   - Damián Szifron
#   - Amole Gupte
#   - Sang-ho Yeon
#   - Alper Caglar
#   - Galder Gaztelu-Urrutia

# %% [markdown]
# With this function we can list the actors in the cluster who worked with the popular directors.

# %%
from Actor_Director_Graph.actor_director_functions import list_actors_who_worked_with_popular_directors_in_cluster
# For each cluster, list actors who worked with popular directors
#list_actors_who_worked_with_popular_directors_in_cluster(cluster_to_nodes, cluster_popular_directors, actors_director_graph)

# %% [markdown]
# We have a Celebrity dataset which sort the most popular actors with a popularity sort. We check which cluster contains popular actors and we take the mean popularity of the popular actors.

# %%
from Actor_Director_Graph.actor_director_functions import clusters_by_average_actors_popularity

# Load celebrity data
df_celebrity = pd.read_csv('../Datasets/Celebrity.csv', index_col=0)

actor_popularity_map, cluster_avg_popularity, cluster_number_of_popular_actors = clusters_by_average_actors_popularity(df_celebrity, cluster_to_nodes)
# Out:
# Clusters ranked by average actor popularity:
# Cluster 26: 44.79 from 1 actors.
# This is the 0.3333333333333333 of the cluster.
#
# Cluster 9: 43.68 from 76 actors.
# This is the 0.13893967093235832 of the cluster.
#
# Cluster 12: 39.47 from 46 actors.
# This is the 0.14790996784565916 of the cluster.
#
# Cluster 16: 38.78 from 6 actors.
# This is the 0.046153846153846156 of the cluster.
#
# Cluster 6: 38.38 from 103 actors.
# This is the 0.13188220230473752 of the cluster.
#
# Cluster 3: 38.01 from 655 actors.
# This is the 0.18730340291678582 of the cluster.
#
# Cluster 13: 37.80 from 13 actors.
# This is the 0.04744525547445255 of the cluster.
#
# Cluster 2: 37.06 from 879 actors.
# This is the 0.2322938689217759 of the cluster.
#
# Cluster 1: 36.92 from 1024 actors.
# This is the 0.23698218005091415 of the cluster.
#
# Cluster 11: 36.74 from 30 actors.
# This is the 0.08670520231213873 of the cluster.
#
# Cluster 4: 36.28 from 131 actors.
# This is the 0.05603079555175364 of the cluster.
#
# Cluster 19: 35.46 from 7 actors.
# This is the 0.21212121212121213 of the cluster.
#
# Cluster 17: 34.39 from 17 actors.
# This is the 0.19767441860465115 of the cluster.
#
# Cluster 5: 34.08 from 120 actors.
# This is the 0.11059907834101383 of the cluster.
#
# Cluster 10: 34.03 from 23 actors.
# This is the 0.044145873320537425 of the cluster.
#
# Cluster 7: 33.25 from 63 actors.
# This is the 0.08936170212765958 of the cluster.
#
# Cluster 0: 32.74 from 636 actors.
# This is the 0.1151131221719457 of the cluster.
#
# Cluster 15: 32.55 from 24 actors.
# This is the 0.1791044776119403 of the cluster.
#
# Cluster 8: 32.22 from 25 actors.
# This is the 0.03607503607503607 of the cluster.
#
# Cluster 14: 26.72 from 2 actors.
# This is the 0.012987012987012988 of the cluster.
#
# Cluster 22: 23.19 from 1 actors.
# This is the 0.2 of the cluster.

# %% [markdown]
# Here we list the clusters with the highest degree centrality, the clusters where the percentage of directors who are popular are the higest, and the clusters where the average popularity of popular directors in the cluster are the highest. We can see that the clusters with the highest node centrality and, clusters with the highest director popularity percentage are really overlapping. This is not the case with the average popularity in the cluster, but this is also due to the fact that the average popularity of directors are not spread out that much, ranging only from approximately 30 to 59 from the lowest to the highest.

# %%
from Actor_Director_Graph.actor_director_functions import show_clusters_centrality_vs_popularity_table

show_clusters_centrality_vs_popularity_table([lst[0] for lst in sorted_by_average_centrality],sorted(cluster_popular_directors_percentages, key=cluster_popular_directors_percentages.get, reverse=True),sorted(cluster_avg_popularity, key=cluster_avg_popularity.get, reverse=True), 10 )
# Out:
# Degree centrality         Popular clusters     Average popularity clusters
# --------------------------------------------------------------------------------
# Cluster 2*                    Cluster 9*          Cluster 26
# Cluster 1*                    Cluster 1*          Cluster 9*
# Cluster 3*                    Cluster 3*          Cluster 12*
# Cluster 19                     Cluster 2*          Cluster 16
# Cluster 12*                    Cluster 15*          Cluster 6*
# Cluster 5*                    Cluster 5*          Cluster 3*
# Cluster 15*                    Cluster 6*          Cluster 13
# Cluster 9*                    Cluster 13           Cluster 2*
# Cluster 6*                    Cluster 12*          Cluster 1*
# Cluster 0                     Cluster 11           Cluster 11

# %% [markdown]
# Sentiment analysis on movie's descriptions.

# %%
word_scores = {}
with open("labMIT-1.0.txt", 'r', encoding='utf-8') as f:
            next(f)
            for line in f:
                parts = line.strip().split('\t')
                if len(parts) >= 3:
                    word = parts[0].lower()
                    happiness_score = float(parts[2])
                    word_scores[word] = happiness_score

# %%
import nltk

nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/dhanna/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/dhanna/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/dhanna/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/dhanna/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Movies in Each Cluster
#
# Now let's iterate through each cluster and collect all the movies associated with directors in those clusters.

# %%
from Actor_Director_Graph.cluster_movies_analysis import (
    collect_cluster_movies,
    get_unique_movies_per_cluster,
    print_cluster_movies_summary,
    print_cluster_movies_detail,
)

# Collect all movies for each cluster
cluster_movies = collect_cluster_movies(
    cluster_to_nodes=cluster_to_nodes,
    df_actors=df_actors,
    movie_directors_dict=movie_directors_dict,
    name_lookup=name_lookup
)

# Get unique movies (not actor-movie pairs)
cluster_unique_movies = get_unique_movies_per_cluster(cluster_movies)

# Print summary
summary = print_cluster_movies_summary(cluster_unique_movies, cluster_to_nodes, top_clusters=20)
# Out:
# Building director-to-movies mapping...
# Found movies for 17170 directors
#
# Collecting movies for each cluster...
#   Cluster  0:  15976 actor-movie entries,  4092 unique films, 2583 directors
#   Cluster  1:  24000 actor-movie entries,  2761 unique films, 1502 directors
#   Cluster  2:  23995 actor-movie entries,  3278 unique films, 1487 directors
#   Cluster  3:  14223 actor-movie entries,  2665 unique films, 1337 directors
#   Cluster  4:   6296 actor-movie entries,  2848 unique films, 1725 directors
#   Cluster  5:   4041 actor-movie entries,   786 unique films,  573 directors
#   Cluster  6:   1982 actor-movie entries,   460 unique films,  335 directors
#   Cluster  7:   1845 actor-movie entries,   485 unique films,  361 directors
#   Cluster  8:   1047 actor-movie entries,   734 unique films,  452 directors
#   Cluster  9:   1251 actor-movie entries,   272 unique films,  219 directors
#   Cluster 10:   1314 actor-movie entries,   611 unique films,  352 directors
#   Cluster 11:    700 actor-movie entries,   389 unique films,  202 directors
#   Cluster 12:   1216 actor-movie entries,   161 unique films,  139 directors
#   Cluster 13:    463 actor-movie entries,   277 unique films,  195 directors
#   Cluster 14:    298 actor-movie entries,    36 unique films,  104 directors
#   Cluster 15:    341 actor-movie entries,    74 unique films,   53 directors
#   Cluster 16:    349 actor-movie entries,    46 unique films,   73 directors
#   Cluster 17:    181 actor-movie entries,    50 unique films,   42 directors
#   Cluster 18:     43 actor-movie entries,    38 unique films,   30 directors
#   Cluster 19:    118 actor-movie entries,    11 unique films,   15 directors
#   Cluster 20:     10 actor-movie entries,    10 unique films,    8 directors
#   Cluster 21:     12 actor-movie entries,     9 unique films,   11 directors
#   Cluster 22:      6 actor-movie entries,     3 unique films,    4 directors
#   Cluster 23:      3 actor-movie entries,     2 unique films,    3 directors
#   Cluster 24:      3 actor-movie entries,     3 unique films,    3 directors
#   Cluster 25:      2 actor-movie entries,     2 unique films,    2 directors
#   Cluster 26:      3 actor-movie entries,     2 unique films,    2 directors
#   Cluster 27:      3 actor-movie entries,     1 unique films,    1 directors
#   Cluster 28:      2 actor-movie entries,     1 unique films,    2 directors
#   Cluster 29:      1 actor-movie entries,     1 unique films,    1 directors
# Movies by cluster - Summary
# Cluster  Movies   Members  Avg Rating   Year Range
# ------------------------------------------------------------
# 0        4092     5525     4.82         1990-2021
# 2        3278     3784     5.87         1990-2021
# 4        2848     2338     5.98         1990-2021
# 1        2761     4321     5.70         1990-2021
# 3        2665     3497     6.01         1990-2021
# 5        786      1085     6.10         1990-2021
# 8        734      693      5.76         1990-2021
# 10       611      521      5.88         1990-2021
# 7        485      705      5.54         1991-2021
# 6        460      781      5.81         1990-2021
# 11       389      346      5.99         1990-2021
# 13       277      274      6.54         1992-2020
# 9        272      547      5.50         1990-2021
# 12       161      311      5.55         1990-2021
# 15       74       134      5.68         1991-2020
# 17       50       86       5.27         1991-2020
# 16       46       130      5.55         1995-2020
# 18       38       39       5.59         2004-2020
# 14       36       154      4.26         2005-2020
# 19       11       33       5.15         1990-2018

# %%
cluster_movies[28]
# Out:
# [{'director': 'Amar Adatia',
#   'director_id': 'nm3720875',
#   'film': 'Gangsters Gamblers Geezers',
#   'film_id': 'tt2215211',
#   'year': 2016,
#   'actor': 'Rahul Kohli',
#   'rating': 5.0,
#   'votes': 743},
#  {'director': 'Peter Peralta',
#   'director_id': 'nm1408676',
#   'film': 'Gangsters Gamblers Geezers',
#   'film_id': 'tt2215211',
#   'year': 2016,
#   'actor': 'Rahul Kohli',
#   'rating': 5.0,
#   'votes': 743}]

# %%
len(cluster_unique_movies)
# Out:
# 30

# %%
'''
from Actor_Director_Graph.sentiment_analysis import calculate_sentiment_labmit

sentiment_scores_of_clusters = {}
movies_sentiment ={}
sentiment_scores_of_genres_in_clusters = {}

for cluster in cluster_unique_movies:
    genre_count = {}
    cluster_sentiment_score = 0
    sentiment_scores_of_genres_in_clusters[cluster] = {}
    for movie in cluster_movies[cluster]:
        film_id = movie['film_id']
        description = str(df_movies_imdb[df_movies_imdb.index == film_id]['description'])
        movies_sentiment[movie['film_id']] ={}

        sentiment = calculate_sentiment_labmit(description, word_scores)['labmit_mean']
        matching_rows = df_movies_imdb[df_movies_imdb.index == film_id]
        if not matching_rows.empty:
            movies_sentiment[film_id]['genres'] = df_movies_imdb[df_movies_imdb.index == film_id]['genre'].values[0].split(', ')
            movies_sentiment[film_id]['sentiment'] = sentiment
        cluster_sentiment_score += sentiment


        if len(matching_rows) > 0:
            for i in range(len(movies_sentiment[film_id]['genres'])):
                genre = movies_sentiment[film_id]['genres'][i]
                if genre not in sentiment_scores_of_genres_in_clusters[cluster]:
                    sentiment_scores_of_genres_in_clusters[cluster][genre] = 0
                sentiment_scores_of_genres_in_clusters[cluster][genre]+= movies_sentiment[film_id]['sentiment']
                if not genre in genre_count:
                    genre_count[genre] = 0
                genre_count[genre] +=1
    for key in sentiment_scores_of_genres_in_clusters[cluster]:
        sentiment_scores_of_genres_in_clusters[cluster][key] /= genre_count[key]

    if len(cluster_movies[cluster]) != 0:
        sentiment_scores_of_clusters[cluster] = cluster_sentiment_score / len(cluster_movies[cluster])
    else:
        sentiment_scores_of_clusters[cluster] = 0

for key, value in sentiment_scores_of_clusters.items():
    print(f"The sentiment of cluster {key} is {value}.")
'''
# Out:
# '\nfrom Actor_Director_Graph.sentiment_analysis import calculate_sentiment_labmit\n\nsentiment_scores_of_clusters = {}\nmovies_sentiment ={}\nsentiment_scores_of_genres_in_clusters = {}\n\nfor cluster in cluster_unique_movies:\n    genre_count = {}\n    cluster_sentiment_score = 0\n    sentiment_scores_of_genres_in_clusters[cluster] = {}\n    for movie in cluster_movies[cluster]:\n        film_id = movie[\'film_id\']\n        description = str(df_movies_imdb[df_movies_imdb.index == film_id][\'description\'])\n        movies_sentiment[movie[\'film_id\']] ={}\n\n        sentiment = calculate_sentiment_labmit(description, word_scores)[\'labmit_mean\']\n        matching_rows = df_movies_imdb[df_movies_imdb.index == film_id]\n        if not matching_rows.empty:\n            movies_sentiment[film_id][\'genres\'] = df_movies_imdb[df_movies_imdb.index == film_id][\'genre\'].values[0].split(\', \')\n            movies_sentiment[film_id][\'sentiment\'] = sentiment\n        cluster_sentiment_score += sentiment\n\n\n        if len(matching_rows) > 0:\n            for i in range(len(movies_sentiment[film_id][\'genres\'])):\n                genre = movies_sentiment[film_id][\'genres\'][i]\n                if genre not in sentiment_scores_of_genres_in_clusters[cluster]:\n                    sentiment_scores_of_genres_in_clusters[cluster][genre] = 0\n                sentiment_scores_of_genres_in_clusters[cluster][genre]+= movies_sentiment[film_id][\'sentiment\']\n                if not genre in genre_count:\n                    genre_count[genre] = 0\n                genre_count[genre] +=1\n    for key in sentiment_scores_of_genres_in_clusters[cluster]:\n        sentiment_scores_of_genres_in_clusters[cluster][key] /= genre_count[key]\n\n    if len(cluster_movies[cluster]) != 0:\n        sentiment_scores_of_clusters[cluster] = cluster_sentiment_score / len(cluster_movies[cluster])\n    else:\n        sentiment_scores_of_clusters[cluster] = 0\n\nfor key, value in sentiment_scores_of_clusters.items():\n    print(f"The sentiment of cluster {key} is {value}.")\n'

# %% [markdown]
# We save the sentiment scores into files, because calculating them takes nearly 15 minutes.

# %%
'''
import json
sentiment_scores_of_clusters= {int(k): v for k, v in sentiment_scores_of_clusters.items()}
with open("sentiment_scores_of_clusters.json", "w") as f:
    json.dump(sentiment_scores_of_clusters, f, indent=4)

sentiment_scores_of_genres_in_clusters= {int(k): v for k, v in sentiment_scores_of_genres_in_clusters.items()}
with open("sentiment_scores_of_genres_in_clusters.json", "w") as f:
    json.dump(sentiment_scores_of_genres_in_clusters, f, indent=4)


'''
# Out:
# '\nimport json\nsentiment_scores_of_clusters= {int(k): v for k, v in sentiment_scores_of_clusters.items()}\nwith open("sentiment_scores_of_clusters.json", "w") as f:\n    json.dump(sentiment_scores_of_clusters, f, indent=4)\n\nsentiment_scores_of_genres_in_clusters= {int(k): v for k, v in sentiment_scores_of_genres_in_clusters.items()}\nwith open("sentiment_scores_of_genres_in_clusters.json", "w") as f:\n    json.dump(sentiment_scores_of_genres_in_clusters, f, indent=4)\n\n\n'

# %%
import json
with open("sentiment_scores_of_clusters.json", "r") as f:
    sentiment_scores_of_clusters = json.load(f)

with open("sentiment_scores_of_genres_in_clusters.json", "r") as f:
    sentiment_scores_of_genres_in_clusters = json.load(f)

# %% [markdown]
# Here we have the average sentiment of each clusters.

# %%
for key, value in sentiment_scores_of_clusters.items():
    print(f"The sentiment of cluster {key} is {value}.")
# Out:
# The sentiment of cluster 0 is 5.479113772630066.
# The sentiment of cluster 1 is 5.53724802407328.
# The sentiment of cluster 2 is 5.485436602405765.
# The sentiment of cluster 3 is 5.508301625665444.
# The sentiment of cluster 4 is 5.534178756621314.
# The sentiment of cluster 5 is 5.499562305081998.
# The sentiment of cluster 6 is 5.4816918148002545.
# The sentiment of cluster 7 is 5.439141344473068.
# The sentiment of cluster 8 is 5.528802213307235.
# The sentiment of cluster 9 is 5.507927609050488.
# The sentiment of cluster 10 is 5.473491127509386.
# The sentiment of cluster 11 is 5.516682534925383.
# The sentiment of cluster 12 is 5.499879750161189.
# The sentiment of cluster 13 is 5.4596649298625515.
# The sentiment of cluster 14 is 5.304382236518119.
# The sentiment of cluster 15 is 5.577312544819136.
# The sentiment of cluster 16 is 5.7033100377813994.
# The sentiment of cluster 17 is 5.524730261144626.
# The sentiment of cluster 18 is 5.57184277995906.
# The sentiment of cluster 19 is 5.520451786443312.
# The sentiment of cluster 20 is 5.514954545454545.
# The sentiment of cluster 21 is 5.554307359307359.
# The sentiment of cluster 22 is 5.534666666666666.
# The sentiment of cluster 23 is 5.467703703703703.
# The sentiment of cluster 24 is 5.633333333333334.
# The sentiment of cluster 25 is 5.4495000000000005.
# The sentiment of cluster 26 is 5.633888888888889.
# The sentiment of cluster 27 is 5.731111111111111.
# The sentiment of cluster 28 is 5.577142857142857.
# The sentiment of cluster 29 is 5.634545454545455.

# %%
from matplotlib import pyplot as plt
import numpy as np
keys = list(sentiment_scores_of_clusters.keys())
values = list(sentiment_scores_of_clusters.values())

outlier_clusters = {k: v for k, v in sentiment_scores_of_clusters.items() if v < 4}
main_clusters = {k: v for k, v in sentiment_scores_of_clusters.items() if v >= 4}

main_keys = list(main_clusters.keys())
main_values = list(main_clusters.values())

fig, ax = plt.subplots(figsize=(14, 8))


colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(main_keys)))


bars = ax.bar(main_keys, main_values, color=colors, edgecolor='black', linewidth=0.5)
ax.set_ylim(5.0, 5.8)


for bar, val in zip(bars, main_values):
    ax.text(bar.get_x() + bar.get_width()/2, val + 0.01,
            f'{val:.2f}', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Add cluster names inside the bars (vertical text)
for bar, key in zip(bars, main_keys):
    name = cluster_names.get(int(key), f'Cluster {key}')
    ax.text(bar.get_x() + bar.get_width()/2, 5.01,
            name, ha='center', va='bottom', fontsize=10, rotation=90,
            color='black', clip_on=True)

mean_val = np.mean(main_values)
ax.axhline(y=mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')

ax.set_xlabel('Community ID', fontsize=14)
ax.set_ylabel('Sentiment Score', fontsize=14)
ax.set_title('Average Sentiment Score of Communities using LabMT\n(Zoomed View: 5.0-5.8 Range)',
             fontsize=14, fontweight='bold')

ax.set_xticks(main_keys)
ax.tick_params(axis='both', labelsize=10)

ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True)


ax.legend(fontsize=12, loc='upper right')

plt.tight_layout()
plt.savefig('sentiment_scores_by_communities_using_labmit.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# WWe did a sentiment analysis with a Hugging Face pipeline, using the "sentiment-analysis" model. (https://huggingface.co/blog/sentiment-analysis-python) This models runs for nearly one and a half hour so we saved the outcome to the llm_sentiment_scores_of_clusters.npy.

# %%
'''
from tqdm.auto import tqdm
from Actor_Director_Graph.sentiment_analysis import calculate_sentiment

llm_sentiment_scores_of_clusters = {}

for cluster in tqdm(cluster_unique_movies):
    # Collect all descriptions for this cluster
    descriptions = []
    for movie in cluster_movies[cluster]:
        description = str(df_movies_imdb[df_movies_imdb.index == movie['film_id']]['description'].values)
        if description and description != 'nan':
            descriptions.append(description)

    # Batch process all descriptions at once
    if descriptions:
        sentiment_results = calculate_sentiment(descriptions, batch_size=32)


        sentiment_scores = []
        for result in sentiment_results:
            if result:
                if result['label'] == 'POSITIVE':
                    sentiment_scores.append(result['score'])
                else:  # NEGATIVE
                    sentiment_scores.append(1 - result['score'])

        # Calculate average sentiment for the cluster
        if sentiment_scores:
            llm_sentiment_scores_of_clusters[cluster] = sum(sentiment_scores) / len(sentiment_scores)
        else:
            llm_sentiment_scores_of_clusters[cluster] = 0.5  # neutral default
    else:
        llm_sentiment_scores_of_clusters[cluster] = 0.5  # neutral default
'''
# Out:
# "\nfrom tqdm.auto import tqdm\nfrom Actor_Director_Graph.sentiment_analysis import calculate_sentiment\n\nllm_sentiment_scores_of_clusters = {}\n\nfor cluster in tqdm(cluster_unique_movies):\n    # Collect all descriptions for this cluster\n    descriptions = []\n    for movie in cluster_movies[cluster]:\n        description = str(df_movies_imdb[df_movies_imdb.index == movie['film_id']]['description'].values)\n        if description and description != 'nan':\n            descriptions.append(description)\n\n    # Batch process all descriptions at once\n    if descriptions:\n        sentiment_results = calculate_sentiment(descriptions, batch_size=32)\n\n\n        sentiment_scores = []\n        for result in sentiment_results:\n            if result:\n                if result['label'] == 'POSITIVE':\n                    sentiment_scores.append(result['score'])\n                else:  # NEGATIVE\n                    sentiment_scores.append(1 - result['score'])\n\n        # Calculate average sentiment for the cluster\n        if sentiment_scores:\n            llm_sentiment_scores_of_clusters[cluster] = sum(sentiment_scores) / len(sentiment_scores)\n        else:\n            llm_sentiment_scores_of_clusters[cluster] = 0.5  # neutral default\n    else:\n        llm_sentiment_scores_of_clusters[cluster] = 0.5  # neutral default\n"

# %% [markdown]
# Here we load the precomputed llm sentiment scores from the of_clusters from the llm_sentiment_scores_of_clusters.npy file.

# %%
#np.save("llm_sentiment_scores_of_clusters", llm_sentiment_scores_of_clusters)
_llm_sentiment_scores_of_clusters = np.load("llm_sentiment_scores_of_clusters.npy", allow_pickle=True).item()
print(_llm_sentiment_scores_of_clusters)
# Out:
# {0: 0.49884087357409157, 1: 0.6256001282718563, 2: 0.0012641549110412598, 3: 0.5415876712787356, 4: 0.42303328770251314, 5: 0.5896448723985928, 6: 0.840635135769844, 7: 0.610425024712801, 8: 0.5329450638063492, 9: 0.6410132329743188, 10: 0.39829768737157184, 11: 0.5422851474760956, 12: 0.6575550651005484, 13: 0.16385726506016643, 14: 0.686577320098877, 15: 0.6322006583213806, 16: 0.6134870300690333, 17: 0.6334950675000001, 18: 0.5916924473563748, 19: 0.5826734955802735, 20: 0.6226212937088227, 21: 0.6317983905134885, 22: 0.583894481598587, 23: 0.704132382247759, 24: 0.6671978970053335, 25: 0.9631664355595907, 26: 0.9710230032602946, 27: 0.5427695678586071, 28: 0.9991794705390931}

# %% [markdown]
# This is the barchart of the sentiment of each clusters using Hugging Face's pipeline. A sentiment is if it is close to 1 and negative if it is close to 0.

# %%
from matplotlib import pyplot as plt

# Extract keys and values from the dictionary
keys = list(_llm_sentiment_scores_of_clusters.keys())
values = list(_llm_sentiment_scores_of_clusters.values())

# Create the bar chart
plt.bar(keys, values)
plt.xlabel('Cluster ID')
plt.ylabel('Sentiment score')
plt.title('Average sentiment score of the clusters from 0 to 1')
plt.savefig('sentiment_scores_by_clusters_using_hugging_face.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Analyze the clusters by genre and production companies
# Genre distribution across different clusters.

# %%
from Actor_Director_Graph.cluster_attribute_analysis import (
    map_movies_to_attributes,
    analyze_attribute_distribution,
    get_specialization_score,
    compare_clusters_by_attribute,
    visualize_top_attributes_by_cluster,
    print_specialization_ranking,
    create_attribute_heatmap
)

# Map movies to genres
cluster_genres = map_movies_to_attributes(cluster_movies, df_movies_imdb, analysis_type='genre')

print(f"\nWe found genres for {len(cluster_genres)} clusters")
# Out:
# We found genres for 30 clusters

# %%
# Analyze genre distribution for each cluster
cluster_genre_stats = analyze_attribute_distribution(
    cluster_genres,
    cluster_to_nodes,
    analysis_type='genre',
    top_n=10
)
# Out:
# Genre analysis by cluster
#
# Cluster 0 (5525 movies)
#   Total movies which have genres information: 32840
#   From this, there was  21 number of genres:
#   Top 10 genres:
#      1. Drama                                6141 ( 18.7%)
#      2. Comedy                               4289 ( 13.1%)
#      3. Thriller                             4053 ( 12.3%)
#      4. Action                               4017 ( 12.2%)
#      5. Horror                               3672 ( 11.2%)
#      6. Crime                                2164 (  6.6%)
#      7. Romance                              1432 (  4.4%)
#      8. Adventure                            1376 (  4.2%)
#      9. Sci-Fi                               1295 (  3.9%)
#     10. Mystery                              1160 (  3.5%)
#
# Cluster 1 (4321 movies)
#   Total movies which have genres information: 52264
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Comedy                              16916 ( 32.4%)
#      2. Drama                                9856 ( 18.9%)
#      3. Romance                              5208 ( 10.0%)
#      4. Adventure                            3444 (  6.6%)
#      5. Action                               2845 (  5.4%)
#      6. Crime                                2556 (  4.9%)
#      7. Animation                            2036 (  3.9%)
#      8. Family                               1606 (  3.1%)
#      9. Thriller                             1593 (  3.0%)
#     10. Horror                               1112 (  2.1%)
#
# Cluster 2 (3784 movies)
#   Total movies which have genres information: 56563
#   From this, there was  21 number of genres:
#   Top 10 genres:
#      1. Drama                               16453 ( 29.1%)
#      2. Comedy                               6936 ( 12.3%)
#      3. Crime                                5886 ( 10.4%)
#      4. Thriller                             5006 (  8.9%)
#      5. Action                               4753 (  8.4%)
#      6. Romance                              4041 (  7.1%)
#      7. Mystery                              2337 (  4.1%)
#      8. Adventure                            1975 (  3.5%)
#      9. Biography                            1834 (  3.2%)
#     10. Horror                               1416 (  2.5%)
#
# Cluster 3 (3497 movies)
#   Total movies which have genres information: 32937
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Drama                                8427 ( 25.6%)
#      2. Comedy                               4500 ( 13.7%)
#      3. Romance                              2767 (  8.4%)
#      4. Action                               2498 (  7.6%)
#      5. Adventure                            2175 (  6.6%)
#      6. Thriller                             2127 (  6.5%)
#      7. Crime                                1861 (  5.7%)
#      8. Biography                            1289 (  3.9%)
#      9. Fantasy                              1126 (  3.4%)
#     10. Horror                               1123 (  3.4%)
#
# Cluster 4 (2338 movies)
#   Total movies which have genres information: 11783
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Drama                                3840 ( 32.6%)
#      2. Comedy                               2191 ( 18.6%)
#      3. Romance                              1007 (  8.5%)
#      4. Thriller                              710 (  6.0%)
#      5. Crime                                 685 (  5.8%)
#      6. Action                                485 (  4.1%)
#      7. Horror                                471 (  4.0%)
#      8. Adventure                             421 (  3.6%)
#      9. Mystery                               342 (  2.9%)
#     10. Fantasy                               340 (  2.9%)
#
# Cluster 5 (1085 movies)
#   Total movies which have genres information: 10949
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Animation                            2980 ( 27.2%)
#      2. Adventure                            2050 ( 18.7%)
#      3. Comedy                               1739 ( 15.9%)
#      4. Action                               1156 ( 10.6%)
#      5. Drama                                 890 (  8.1%)
#      6. Family                                806 (  7.4%)
#      7. Fantasy                               241 (  2.2%)
#      8. Crime                                 207 (  1.9%)
#      9. Sci-Fi                                204 (  1.9%)
#     10. Thriller                              195 (  1.8%)
#
# Cluster 6 (781 movies)
#   Total movies which have genres information: 4396
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Drama                                1167 ( 26.5%)
#      2. Comedy                                439 ( 10.0%)
#      3. Action                                421 (  9.6%)
#      4. Thriller                              368 (  8.4%)
#      5. Crime                                 318 (  7.2%)
#      6. Horror                                296 (  6.7%)
#      7. Mystery                               283 (  6.4%)
#      8. Romance                               267 (  6.1%)
#      9. Adventure                             211 (  4.8%)
#     10. Fantasy                               165 (  3.8%)
#
# Cluster 7 (705 movies)
#   Total movies which have genres information: 3919
#   From this, there was  18 number of genres:
#   Top 10 genres:
#      1. Drama                                 773 ( 19.7%)
#      2. Horror                                687 ( 17.5%)
#      3. Comedy                                638 ( 16.3%)
#      4. Thriller                              410 ( 10.5%)
#      5. Fantasy                               299 (  7.6%)
#      6. Mystery                               221 (  5.6%)
#      7. Crime                                 207 (  5.3%)
#      8. Romance                               187 (  4.8%)
#      9. Action                                163 (  4.2%)
#     10. Sci-Fi                                 88 (  2.2%)
#
# Cluster 8 (693 movies)
#   Total movies which have genres information: 2378
#   From this, there was  19 number of genres:
#   Top 10 genres:
#      1. Drama                                 661 ( 27.8%)
#      2. Comedy                                390 ( 16.4%)
#      3. Action                                370 ( 15.6%)
#      4. Romance                               324 ( 13.6%)
#      5. Crime                                 142 (  6.0%)
#      6. Thriller                              130 (  5.5%)
#      7. Musical                                77 (  3.2%)
#      8. Mystery                                49 (  2.1%)
#      9. Adventure                              44 (  1.9%)
#     10. Family                                 42 (  1.8%)
#
# Cluster 9 (547 movies)
#   Total movies which have genres information: 2802
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Drama                                 678 ( 24.2%)
#      2. Comedy                                380 ( 13.6%)
#      3. Action                                308 ( 11.0%)
#      4. Adventure                             245 (  8.7%)
#      5. Romance                               203 (  7.2%)
#      6. Crime                                 185 (  6.6%)
#      7. Sci-Fi                                156 (  5.6%)
#      8. Thriller                              146 (  5.2%)
#      9. Horror                                119 (  4.2%)
#     10. Mystery                                87 (  3.1%)
#
# Cluster 10 (521 movies)
#   Total movies which have genres information: 2665
#   From this, there was  20 number of genres:
#   Top 10 genres:
#      1. Drama                                 853 ( 32.0%)
#      2. Comedy                                331 ( 12.4%)
#      3. Thriller                              226 (  8.5%)
#      4. Crime                                 194 (  7.3%)
#      5. Action                                192 (  7.2%)
#      6. Romance                               159 (  6.0%)
#      7. Horror                                140 (  5.3%)
#      8. Mystery                               119 (  4.5%)
#      9. Adventure                              87 (  3.3%)
#     10. Family                                 81 (  3.0%)
#
# Cluster 11 (346 movies)
#   Total movies which have genres information: 1558
#   From this, there was  18 number of genres:
#   Top 10 genres:
#      1. Drama                                 339 ( 21.8%)
#      2. Action                                282 ( 18.1%)
#      3. Comedy                                259 ( 16.6%)
#      4. Romance                               157 ( 10.1%)
#      5. Crime                                 135 (  8.7%)
#      6. Adventure                              74 (  4.7%)
#      7. Fantasy                                50 (  3.2%)
#      8. Thriller                               49 (  3.1%)
#      9. History                                44 (  2.8%)
#     10. Family                                 37 (  2.4%)
#
# Cluster 12 (311 movies)
#   Total movies which have genres information: 2752
#   From this, there was  19 number of genres:
#   Top 10 genres:
#      1. Drama                                 622 ( 22.6%)
#      2. Comedy                                271 (  9.8%)
#      3. Thriller                              245 (  8.9%)
#      4. Action                                208 (  7.6%)
#      5. Horror                                201 (  7.3%)
#      6. Sci-Fi                                197 (  7.2%)
#      7. Adventure                             193 (  7.0%)
#      8. Romance                               166 (  6.0%)
#      9. Crime                                 141 (  5.1%)
#     10. Fantasy                               105 (  3.8%)
#
# Cluster 13 (274 movies)
#   Total movies which have genres information: 1041
#   From this, there was  19 number of genres:
#   Top 10 genres:
#      1. Drama                                 272 ( 26.1%)
#      2. Action                                152 ( 14.6%)
#      3. Comedy                                119 ( 11.4%)
#      4. Thriller                               97 (  9.3%)
#      5. Crime                                  75 (  7.2%)
#      6. Romance                                60 (  5.8%)
#      7. Fantasy                                43 (  4.1%)
#      8. Adventure                              37 (  3.6%)
#      9. Sci-Fi                                 33 (  3.2%)
#     10. History                                29 (  2.8%)
#
# Cluster 14 (154 movies)
#   Total movies which have genres information: 778
#   From this, there was  14 number of genres:
#   Top 10 genres:
#      1. Action                                228 ( 29.3%)
#      2. Comedy                                209 ( 26.9%)
#      3. Animation                             176 ( 22.6%)
#      4. Horror                                 63 (  8.1%)
#      5. Crime                                  27 (  3.5%)
#      6. Thriller                               20 (  2.6%)
#      7. Sci-Fi                                 17 (  2.2%)
#      8. Drama                                  15 (  1.9%)
#      9. Mystery                                 9 (  1.2%)
#     10. Family                                  6 (  0.8%)
#
# Cluster 15 (134 movies)
#   Total movies which have genres information: 658
#   From this, there was  17 number of genres:
#   Top 10 genres:
#      1. Drama                                 188 ( 28.6%)
#      2. Thriller                               73 ( 11.1%)
#      3. Comedy                                 68 ( 10.3%)
#      4. Romance                                58 (  8.8%)
#      5. Mystery                                51 (  7.8%)
#      6. Horror                                 42 (  6.4%)
#      7. Biography                              41 (  6.2%)
#      8. Fantasy                                38 (  5.8%)
#      9. Sport                                  23 (  3.5%)
#     10. Crime                                  20 (  3.0%)
#
# Cluster 16 (130 movies)
#   Total movies which have genres information: 730
#   From this, there was  15 number of genres:
#   Top 10 genres:
#      1. Horror                                223 ( 30.5%)
#      2. Drama                                 173 ( 23.7%)
#      3. Comedy                                138 ( 18.9%)
#      4. Thriller                               63 (  8.6%)
#      5. Action                                 35 (  4.8%)
#      6. Crime                                  33 (  4.5%)
#      7. Mystery                                17 (  2.3%)
#      8. Biography                              15 (  2.1%)
#      9. Romance                                10 (  1.4%)
#     10. Music                                  10 (  1.4%)
#
# Cluster 17 (86 movies)
#   Total movies which have genres information: 349
#   From this, there was  15 number of genres:
#   Top 10 genres:
#      1. Comedy                                 65 ( 18.6%)
#      2. Thriller                               59 ( 16.9%)
#      3. Drama                                  56 ( 16.0%)
#      4. Horror                                 40 ( 11.5%)
#      5. Romance                                24 (  6.9%)
#      6. Family                                 20 (  5.7%)
#      7. Adventure                              17 (  4.9%)
#      8. Action                                 14 (  4.0%)
#      9. Animation                              13 (  3.7%)
#     10. Mystery                                12 (  3.4%)
#
# Cluster 18 (39 movies)
#   Total movies which have genres information: 69
#   From this, there was  14 number of genres:
#   Top 10 genres:
#      1. Drama                                  20 ( 29.0%)
#      2. Comedy                                 16 ( 23.2%)
#      3. Romance                                13 ( 18.8%)
#      4. Mystery                                 4 (  5.8%)
#      5. Crime                                   2 (  2.9%)
#      6. Fantasy                                 2 (  2.9%)
#      7. Family                                  2 (  2.9%)
#      8. Action                                  2 (  2.9%)
#      9. War                                     2 (  2.9%)
#     10. Adventure                               2 (  2.9%)
#
# Cluster 19 (33 movies)
#   Total movies which have genres information: 314
#   From this, there was  8 number of genres:
#   Top 8 genres:
#      1. Drama                                 114 ( 36.3%)
#      2. Fantasy                                73 ( 23.2%)
#      3. Animation                              72 ( 22.9%)
#      4. Comedy                                 28 (  8.9%)
#      5. Romance                                18 (  5.7%)
#      6. Action                                  4 (  1.3%)
#      7. Crime                                   3 (  1.0%)
#      8. Horror                                  2 (  0.6%)
#
# Cluster 20 (14 movies)
#   Total movies which have genres information: 14
#   From this, there was  3 number of genres:
#   Top 3 genres:
#      1. Drama                                   8 ( 57.1%)
#      2. Comedy                                  5 ( 35.7%)
#      3. Romance                                 1 (  7.1%)
#
# Cluster 21 (12 movies)
#   Total movies which have genres information: 22
#   From this, there was  9 number of genres:
#   Top 9 genres:
#      1. Comedy                                  7 ( 31.8%)
#      2. Romance                                 4 ( 18.2%)
#      3. Action                                  3 ( 13.6%)
#      4. Crime                                   2 (  9.1%)
#      5. Drama                                   2 (  9.1%)
#      6. Adventure                               1 (  4.5%)
#      7. Family                                  1 (  4.5%)
#      8. Horror                                  1 (  4.5%)
#      9. Thriller                                1 (  4.5%)
#
# Cluster 22 (5 movies)
#   Total movies which have genres information: 4
#   From this, there was  2 number of genres:
#   Top 2 genres:
#      1. Comedy                                  2 ( 50.0%)
#      2. Drama                                   2 ( 50.0%)
#
# Cluster 23 (4 movies)
#   Total movies which have genres information: 5
#   From this, there was  4 number of genres:
#   Top 4 genres:
#      1. Action                                  2 ( 40.0%)
#      2. Adventure                               1 ( 20.0%)
#      3. Comedy                                  1 ( 20.0%)
#      4. Drama                                   1 ( 20.0%)
#
# Cluster 24 (4 movies)
#   Total movies which have genres information: 2
#   From this, there was  1 number of genres:
#   Top 1 genres:
#      1. Drama                                   2 (100.0%)
#
# Cluster 25 (3 movies)
#   Total movies which have genres information: 6
#   From this, there was  4 number of genres:
#   Top 4 genres:
#      1. Action                                  2 ( 33.3%)
#      2. Thriller                                2 ( 33.3%)
#      3. Drama                                   1 ( 16.7%)
#      4. Adventure                               1 ( 16.7%)
#
# Cluster 26 (3 movies)
#   Total movies which have genres information: 2
#   From this, there was  1 number of genres:
#   Top 1 genres:
#      1. Biography                               2 (100.0%)
#
# Cluster 27 (3 movies)
#   Total movies which have genres information: 6
#   From this, there was  2 number of genres:
#   Top 2 genres:
#      1. Action                                  3 ( 50.0%)
#      2. Horror                                  3 ( 50.0%)
#
# Cluster 28 (3 movies)
#   Total movies which have genres information: 2
#   From this, there was  1 number of genres:
#   Top 1 genres:
#      1. Comedy                                  2 (100.0%)
#
# Cluster 29 (3 movies)
#   Total movies which have genres information: 1
#   From this, there was  1 number of genres:
#   Top 1 genres:
#      1. Horror                                  1 (100.0%)

# %% [markdown]
# high diversity score means the cluster works across many genres, while a low score indicates specialization in fewer genres.

# %% [markdown]
# Visualizations to better understand the genre patterns across clusters.

# %%
# Visualize top genres for the largest clusters
fig_genres = visualize_top_attributes_by_cluster(cluster_genre_stats, analysis_type='genre', top_clusters=len(cluster_movies), top_items=5)
# Out:
# Visualization saved as 'cluster_genre_distribution.png'

# %%
# Calculate genre specialization scores and create heatmap
genre_specialization_scores = get_specialization_score(cluster_genres)
print_specialization_ranking(genre_specialization_scores, cluster_genres, analysis_type='genre', show_top_n=3)

# Create genre comparison matrix and heatmap
genre_matrix = compare_clusters_by_attribute(cluster_genres)
df_genre_heatmap = create_attribute_heatmap(genre_matrix, analysis_type='genre', top_n_clusters=len(cluster_movies), top_n_items=15)
# Out:
# Genre Specialization ranking
#
# Most Specialized (focused on fewer genres):
#  1. Cluster 24: Diversity=0.000, Unique=1, Total mentions=2
#       → Top genres: Drama (100.0%)
#  2. Cluster 26: Diversity=0.000, Unique=1, Total mentions=2
#       → Top genres: Biography (100.0%)
#  3. Cluster 28: Diversity=0.000, Unique=1, Total mentions=2
#       → Top genres: Comedy (100.0%)
#  4. Cluster 29: Diversity=0.000, Unique=1, Total mentions=1
#       → Top genres: Horror (100.0%)
#  5. Cluster 14: Diversity=0.671, Unique=14, Total mentions=778
#       → Top genres: Action (29.3%), Comedy (26.9%), Animation (22.6%)
#  6. Cluster 16: Diversity=0.701, Unique=15, Total mentions=730
#       → Top genres: Horror (30.5%), Drama (23.7%), Comedy (18.9%)
#  7. Cluster  5: Diversity=0.706, Unique=20, Total mentions=10949
#       → Top genres: Animation (27.2%), Adventure (18.7%), Comedy (15.9%)
#  8. Cluster  8: Diversity=0.739, Unique=19, Total mentions=2378
#       → Top genres: Drama (27.8%), Comedy (16.4%), Action (15.6%)
#  9. Cluster 19: Diversity=0.748, Unique=8, Total mentions=314
#       → Top genres: Drama (36.3%), Fantasy (23.2%), Animation (22.9%)
# 10. Cluster  1: Diversity=0.749, Unique=20, Total mentions=52264
#       → Top genres: Comedy (32.4%), Drama (18.9%), Romance (10.0%)
#
# Most Diverse (spread across many genres):
#  1. Cluster 27: Diversity=1.000, Unique=2, Total mentions=6
#       → Top genres: Action (50.0%), Horror (50.0%)
#  2. Cluster 22: Diversity=1.000, Unique=2, Total mentions=4
#       → Top genres: Comedy (50.0%), Drama (50.0%)
#  3. Cluster 23: Diversity=0.961, Unique=4, Total mentions=5
#       → Top genres: Action (40.0%), Adventure (20.0%), Comedy (20.0%)
#  4. Cluster 25: Diversity=0.959, Unique=4, Total mentions=6
#       → Top genres: Action (33.3%), Thriller (33.3%), Drama (16.7%)
#  5. Cluster 21: Diversity=0.885, Unique=9, Total mentions=22
#       → Top genres: Comedy (31.8%), Romance (18.2%), Action (13.6%)
#  6. Cluster 17: Diversity=0.866, Unique=15, Total mentions=349
#       → Top genres: Comedy (18.6%), Thriller (16.9%), Drama (16.0%)
#  7. Cluster 12: Diversity=0.860, Unique=19, Total mentions=2752
#       → Top genres: Drama (22.6%), Comedy (9.8%), Thriller (8.9%)
#  8. Cluster  3: Diversity=0.836, Unique=20, Total mentions=32937
#       → Top genres: Drama (25.6%), Comedy (13.7%), Romance (8.4%)
#  9. Cluster 15: Diversity=0.823, Unique=17, Total mentions=658
#       → Top genres: Drama (28.6%), Thriller (11.1%), Comedy (10.3%)
# 10. Cluster  6: Diversity=0.820, Unique=20, Total mentions=4396
#       → Top genres: Drama (26.5%), Comedy (10.0%), Action (9.6%)
# Heatmap saved as 'genre_heatmap.png'

# %%
# Production Company Analysis
# Map movies to production companies
print("Mapping cluster movies to production companies...")
cluster_companies = map_movies_to_attributes(cluster_movies, df_movies_imdb, analysis_type='production_company')

print(f"\nMapped production companies for {len(cluster_companies)} clusters")

# Analyze production company distribution for each cluster
cluster_company_stats = analyze_attribute_distribution(
    cluster_companies,
    cluster_to_nodes,
    analysis_type='production_company',
    top_n=10
)
# Out:
# Mapping cluster movies to production companies...
#
# Mapped production companies for 30 clusters
# Production Company analysis by cluster
#
# Cluster 0 (5525 movies)
#   Total movies which have production companies information: 14564
#   From this, there was  2744 number of production companies:
#   Top 10 production companies:
#      1. Dimension Films                       258 (  1.8%)
#      2. Epic Pictures Group                   208 (  1.4%)
#      3. New Line Cinema                       133 (  0.9%)
#      4. PM Entertainment Group                123 (  0.8%)
#      5. Lionsgate                             112 (  0.8%)
#      6. Columbia Pictures                     104 (  0.7%)
#      7. Deathcember                            96 (  0.7%)
#      8. Miramax                                96 (  0.7%)
#      9. Warner Bros.                           91 (  0.6%)
#     10. Concorde-New Horizons                  88 (  0.6%)
#
# Cluster 1 (4321 movies)
#   Total movies which have production companies information: 22815
#   From this, there was  1588 number of production companies:
#   Top 10 production companies:
#      1. Columbia Pictures                    1187 (  5.2%)
#      2. Universal Pictures                   1072 (  4.7%)
#      3. New Line Cinema                       709 (  3.1%)
#      4. Paramount Pictures                    622 (  2.7%)
#      5. Twentieth Century Fox                 509 (  2.2%)
#      6. Warner Bros.                          451 (  2.0%)
#      7. Relativity Media                      284 (  1.2%)
#      8. Walt Disney Pictures                  278 (  1.2%)
#      9. DreamWorks Animation                  277 (  1.2%)
#     10. Fox 2000 Pictures                     228 (  1.0%)
#
# Cluster 2 (3784 movies)
#   Total movies which have production companies information: 23080
#   From this, there was  1913 number of production companies:
#   Top 10 production companies:
#      1. Warner Bros.                         1101 (  4.8%)
#      2. Universal Pictures                    721 (  3.1%)
#      3. Columbia Pictures                     684 (  3.0%)
#      4. Paramount Pictures                    668 (  2.9%)
#      5. Twentieth Century Fox                 470 (  2.0%)
#      6. Touchstone Pictures                   444 (  1.9%)
#      7. Victoires International               360 (  1.6%)
#      8. DreamWorks                            348 (  1.5%)
#      9. New Line Cinema                       326 (  1.4%)
#     10. Miramax                               287 (  1.2%)
#
# Cluster 3 (3497 movies)
#   Total movies which have production companies information: 13438
#   From this, there was  1613 number of production companies:
#   Top 10 production companies:
#      1. Universal Pictures                    437 (  3.3%)
#      2. Paramount Pictures                    362 (  2.7%)
#      3. Warner Bros.                          353 (  2.6%)
#      4. Walt Disney Pictures                  299 (  2.2%)
#      5. BBC Films                             262 (  1.9%)
#      6. Twentieth Century Fox                 173 (  1.3%)
#      7. British Broadcasting Corporation (BBC)   169 (  1.3%)
#      8. Columbia Pictures                     147 (  1.1%)
#      9. Miramax                               138 (  1.0%)
#     10. Fox Searchlight Pictures              119 (  0.9%)
#
# Cluster 4 (2338 movies)
#   Total movies which have production companies information: 5658
#   From this, there was  1486 number of production companies:
#   Top 10 production companies:
#      1. Cannes Film Festival                  147 (  2.6%)
#      2. Canal+                                 97 (  1.7%)
#      3. Arts+Labor                             92 (  1.6%)
#      4. Zentropa Entertainments                78 (  1.4%)
#      5. Gaumont                                54 (  1.0%)
#      6. Trésor Films                           51 (  0.9%)
#      7. Canal+ España                          50 (  0.9%)
#      8. Why Not Productions                    50 (  0.9%)
#      9. Doha Film Institute                    49 (  0.9%)
#     10. Barefoot Films                         40 (  0.7%)
#
# Cluster 5 (1085 movies)
#   Total movies which have production companies information: 3876
#   From this, there was  459 number of production companies:
#   Top 10 production companies:
#      1. Walt Disney Pictures                  175 (  4.5%)
#      2. Pixar Animation Studios               159 (  4.1%)
#      3. Warner Bros. Animation                110 (  2.8%)
#      4. Aniplex                               105 (  2.7%)
#      5. Paramount Pictures                     96 (  2.5%)
#      6. Universal Pictures                     87 (  2.2%)
#      7. Gainax                                 86 (  2.2%)
#      8. Disney Television Animation            82 (  2.1%)
#      9. Walt Disney Animation Studios          60 (  1.5%)
#     10. Studio Ghibli                          54 (  1.4%)
#
# Cluster 6 (781 movies)
#   Total movies which have production companies information: 1843
#   From this, there was  331 number of production companies:
#   Top 10 production companies:
#      1. Arenamedia                            122 (  6.6%)
#      2. Warner Bros.                           52 (  2.8%)
#      3. Australian Film Finance Corporation (AFFC)    36 (  2.0%)
#      4. Blumhouse Productions                  35 (  1.9%)
#      5. Screen Australia                       33 (  1.8%)
#      6. Twentieth Century Fox                  25 (  1.4%)
#      7. Porchlight Films                       25 (  1.4%)
#      8. Atlas Entertainment                    23 (  1.2%)
#      9. Bad Robot                              23 (  1.2%)
#     10. Carousel Productions (II)              22 (  1.2%)
#
# Cluster 7 (705 movies)
#   Total movies which have production companies information: 1661
#   From this, there was  359 number of production companies:
#   Top 10 production companies:
#      1. Magnet Releasing                      168 ( 10.1%)
#      2. ArtCastle                              50 (  3.0%)
#      3. Borrowtime                             42 (  2.5%)
#      4. Indiecan Entertainment                 36 (  2.2%)
#      5. Snowfort Pictures                      34 (  2.0%)
#      6. Glass Eye Pix                          27 (  1.6%)
#      7. A24                                    22 (  1.3%)
#      8. Promenade Pictures                     22 (  1.3%)
#      9. Dark Sky Films                         17 (  1.0%)
#     10. Autumnwood Media                       16 (  1.0%)
#
# Cluster 8 (693 movies)
#   Total movies which have production companies information: 925
#   From this, there was  428 number of production companies:
#   Top 10 production companies:
#      1. Dharma Productions                     31 (  3.4%)
#      2. Eros International                     27 (  2.9%)
#      3. Mukta Arts                             19 (  2.1%)
#      4. NH Studioz                             19 (  2.1%)
#      5. Yash Raj Films                         18 (  1.9%)
#      6. Aamir Khan Productions                 13 (  1.4%)
#      7. Blockbuster Movie Entertainers         13 (  1.4%)
#      8. Bhansali Productions                   12 (  1.3%)
#      9. Drishyam Films                         10 (  1.1%)
#     10. Capitol Theatre                         9 (  1.0%)
#
# Cluster 9 (547 movies)
#   Total movies which have production companies information: 1170
#   From this, there was  217 number of production companies:
#   Top 10 production companies:
#      1. Walt Disney Pictures                   72 (  6.2%)
#      2. Marvel Studios                         68 (  5.8%)
#      3. Summit Entertainment                   42 (  3.6%)
#      4. Swirl Films                            32 (  2.7%)
#      5. Ex Film Collective                     29 (  2.5%)
#      6. Universal Pictures                     28 (  2.4%)
#      7. Overflow Entertainment                 25 (  2.1%)
#      8. Mandeville Films                       21 (  1.8%)
#      9. Metro-Goldwyn-Mayer (MGM)              18 (  1.5%)
#     10. Yari Film Group Releasing              17 (  1.5%)
#
# Cluster 10 (521 movies)
#   Total movies which have production companies information: 1231
#   From this, there was  308 number of production companies:
#   Top 10 production companies:
#      1. Zentropa Entertainments                45 (  3.7%)
#      2. Nimbus Film Productions                38 (  3.1%)
#      3. Film i Väst                            35 (  2.8%)
#      4. M&M Productions                        24 (  1.9%)
#      5. Nordisk Film                           22 (  1.8%)
#      6. Det Danske Filminstitut                21 (  1.7%)
#      7. Columbia Pictures                      21 (  1.7%)
#      8. Summit Entertainment                   18 (  1.5%)
#      9. FilmDistrict                           18 (  1.5%)
#     10. Netflix                                18 (  1.5%)
#
# Cluster 11 (346 movies)
#   Total movies which have production companies information: 654
#   From this, there was  213 number of production companies:
#   Top 10 production companies:
#      1. Golden Harvest Company                 33 (  5.0%)
#      2. Media Asia Films                       28 (  4.3%)
#      3. China Film Group Corporation (CFGC)    20 (  3.1%)
#      4. Block 2 Pictures                       19 (  2.9%)
#      5. Hitamin                                16 (  2.4%)
#      6. Taipei Golden Horse                    15 (  2.3%)
#      7. China Star Entertainment               13 (  2.0%)
#      8. Film Workshop                          13 (  2.0%)
#      9. Jet Tone Production                    13 (  2.0%)
#     10. Mili Pictures                          12 (  1.8%)
#
# Cluster 12 (311 movies)
#   Total movies which have production companies information: 1115
#   From this, there was  123 number of production companies:
#   Top 10 production companies:
#      1. Elysium Bandini Studios               204 ( 18.3%)
#      2. Columbia Pictures                      81 (  7.3%)
#      3. RabbitBandini Productions              65 (  5.8%)
#      4. Black Sand Pictures                    33 (  3.0%)
#      5. 6 Foot Films                           32 (  2.9%)
#      6. Universal Pictures                     23 (  2.1%)
#      7. Hammerhead Productions                 21 (  1.9%)
#      8. Twentieth Century Fox                  20 (  1.8%)
#      9. TriStar Pictures                       19 (  1.7%)
#     10. Campfire Stories Inc.                  18 (  1.6%)
#
# Cluster 13 (274 movies)
#   Total movies which have production companies information: 397
#   From this, there was  143 number of production companies:
#   Top 10 production companies:
#      1. CJ Entertainment                       66 ( 16.6%)
#      2. Di Bonaventura Pictures                15 (  3.8%)
#      3. Cinereach                              14 (  3.5%)
#      4. SnowPiercer                            11 (  2.8%)
#      5. Barunson E&A                           11 (  2.8%)
#      6. Conspiração Filmes                      9 (  2.3%)
#      7. Fox Searchlight Pictures                9 (  2.3%)
#      8. Kate Street Picture Company             8 (  2.0%)
#      9. Oracle Releasing                        7 (  1.8%)
#     10. 4th Creative Party                      7 (  1.8%)
#
# Cluster 14 (154 movies)
#   Total movies which have production companies information: 277
#   From this, there was  22 number of production companies:
#   Top 10 production companies:
#      1. A Bunch of Filmmakers                 176 ( 63.5%)
#      2. Vestra Pictures                        24 (  8.7%)
#      3. Body Bag Films                         22 (  7.9%)
#      4. Rooster Teeth Productions              11 (  4.0%)
#      5. Frolic Pictures                         5 (  1.8%)
#      6. MAKE GOOD Content                       4 (  1.4%)
#      7. End Cue                                 4 (  1.4%)
#      8. Ruthless Studios                        4 (  1.4%)
#      9. Loveless                                4 (  1.4%)
#     10. My Hero Productions                     3 (  1.1%)
#
# Cluster 15 (134 movies)
#   Total movies which have production companies information: 279
#   From this, there was  52 number of production companies:
#   Top 10 production companies:
#      1. Columbia Pictures                      29 ( 10.4%)
#      2. Cima Productions                       23 (  8.2%)
#      3. Summit Entertainment                   19 (  6.8%)
#      4. Warner Bros.                           13 (  4.7%)
#      5. Fox Searchlight Pictures               11 (  3.9%)
#      6. Indy Entertainment                     10 (  3.6%)
#      7. S Films                                 9 (  3.2%)
#      8. Burgundy Films                          9 (  3.2%)
#      9. New Line Cinema                         8 (  2.9%)
#     10. Blumhouse Productions                   8 (  2.9%)
#
# Cluster 16 (130 movies)
#   Total movies which have production companies information: 331
#   From this, there was  38 number of production companies:
#   Top 10 production companies:
#      1. Black Toffee / SnapperPunchFish        96 ( 29.0%)
#      2. High Performance Films LLC             72 ( 21.8%)
#      3. Fun Size Horror Productions            35 ( 10.6%)
#      4. Bleiberg Entertainment                 12 (  3.6%)
#      5. Grand Peaks Entertainment              12 (  3.6%)
#      6. Maven Pictures                         11 (  3.3%)
#      7. Free Chicken Films                     10 (  3.0%)
#      8. Cinipix                                10 (  3.0%)
#      9. Mule Films                              6 (  1.8%)
#     10. Birthday Suit Productions               6 (  1.8%)
#
# Cluster 17 (86 movies)
#   Total movies which have production companies information: 174
#   From this, there was  43 number of production companies:
#   Top 10 production companies:
#      1. Mystery Productions                    10 (  5.7%)
#      2. Skyline Pictures (II)                  10 (  5.7%)
#      3. Polsky Films                           10 (  5.7%)
#      4. Last Request                            9 (  5.2%)
#      5. Cinerenta Medienbeteiligungs KG         8 (  4.6%)
#      6. BKG2H Productions                       7 (  4.0%)
#      7. Imperial Entertainment                  7 (  4.0%)
#      8. Provident Films                         7 (  4.0%)
#      9. Perfect Weekend                         7 (  4.0%)
#     10. Code Entertainment                      6 (  3.4%)
#
# Cluster 18 (39 movies)
#   Total movies which have production companies information: 36
#   From this, there was  21 number of production companies:
#   Top 10 production companies:
#      1. TAFF Pictures                           5 ( 13.9%)
#      2. FBR Productions                         4 ( 11.1%)
#      3. Ay Yapim                                3 (  8.3%)
#      4. Avsar Film                              3 (  8.3%)
#      5. Fida Film                               3 (  8.3%)
#      6. BRK'S Production                        2 (  5.6%)
#      7. Boyut Film                              2 (  5.6%)
#      8. Asya Film                               1 (  2.8%)
#      9. Dada Film                               1 (  2.8%)
#     10. DFGS Yapim                              1 (  2.8%)
#
# Cluster 19 (33 movies)
#   Total movies which have production companies information: 117
#   From this, there was  10 number of production companies:
#   Top 10 production companies:
#      1. Dutchess Music                         72 ( 61.5%)
#      2. EuropaCorp                             14 ( 12.0%)
#      3. Foxy Films                              9 (  7.7%)
#      4. Michael Cerenzie Productions            8 (  6.8%)
#      5. Spring Creek Productions                5 (  4.3%)
#      6. Parts and Labor                         3 (  2.6%)
#      7. Rockaway the Movie                      3 (  2.6%)
#      8. K.S. Film                               1 (  0.9%)
#      9. Amber Pictures                          1 (  0.9%)
#     10. Vestra Pictures                         1 (  0.9%)
#
# Cluster 20 (14 movies)
#   Total movies which have production companies information: 8
#   From this, there was  8 number of production companies:
#   Top 8 production companies:
#      1. Budapest Filmstúdió                     1 ( 12.5%)
#      2. Eurofilm Stúdió                         1 ( 12.5%)
#      3. Hunnia Filmstúdió                       1 ( 12.5%)
#      4. FilmTeam                                1 ( 12.5%)
#      5. 21st Century DreamQuest Films           1 ( 12.5%)
#      6. Novofilm                                1 ( 12.5%)
#      7. FocusFox Studio                         1 ( 12.5%)
#      8. Honeymood Films                         1 ( 12.5%)
#
# Cluster 21 (12 movies)
#   Total movies which have production companies information: 10
#   From this, there was  8 number of production companies:
#   Top 8 production companies:
#      1. AM Pictures                             2 ( 20.0%)
#      2. NL Film                                 2 ( 20.0%)
#      3. Aydin Film                              1 ( 10.0%)
#      4. Studio 100                              1 ( 10.0%)
#      5. Hope & Glory Pictures International     1 ( 10.0%)
#      6. Lemming Film                            1 ( 10.0%)
#      7. Robin Media                             1 ( 10.0%)
#      8. Steven de Jong Producties               1 ( 10.0%)
#
# Cluster 22 (5 movies)
#   Total movies which have production companies information: 2
#   From this, there was  1 number of production companies:
#   Top 1 production companies:
#      1. Abraxas Film                            2 (100.0%)
#
# Cluster 23 (4 movies)
#   Total movies which have production companies information: 3
#   From this, there was  2 number of production companies:
#   Top 2 production companies:
#      1. HI-AX                                   2 ( 66.7%)
#      2. Studio Saboteur                         1 ( 33.3%)
#
# Cluster 24 (4 movies)
#   Total movies which have production companies information: 2
#   From this, there was  2 number of production companies:
#   Top 2 production companies:
#      1. Jost Hering Filmproduktion              1 ( 50.0%)
#      2. Kineo Filmproduktion                    1 ( 50.0%)
#
# Cluster 25 (3 movies)
#   Total movies which have production companies information: 2
#   From this, there was  2 number of production companies:
#   Top 2 production companies:
#      1. Kruthuset AB                            1 ( 50.0%)
#      2. ElSobky Film                            1 ( 50.0%)
#
# Cluster 26 (3 movies)
#   Total movies which have production companies information: 2
#   From this, there was  1 number of production companies:
#   Top 1 production companies:
#      1. Fulwell 73                              2 (100.0%)
#
# Cluster 27 (3 movies)
#   Total movies which have production companies information: 3
#   From this, there was  1 number of production companies:
#   Top 1 production companies:
#      1. Collingwood Management                  3 (100.0%)
#
# Cluster 28 (3 movies)
#   Total movies which have production companies information: 2
#   From this, there was  1 number of production companies:
#   Top 1 production companies:
#      1. Jaffa Films (II)                        2 (100.0%)
#
# Cluster 29 (3 movies)
#   Total movies which have production companies information: 1
#   From this, there was  1 number of production companies:
#   Top 1 production companies:
#      1. William Winckler Productions            1 (100.0%)

# %% [markdown]
# Visualizations to better understand the production company patterns across clusters.

# %%
# Visualize top production companies for the largest clusters
fig_companies = visualize_top_attributes_by_cluster(cluster_company_stats, analysis_type='production_company', top_clusters=10, top_items=5)

# Calculate production company specialization scores and create heatmap
company_specialization_scores = get_specialization_score(cluster_companies)
print_specialization_ranking(company_specialization_scores, cluster_companies, analysis_type='production_company', show_top_n=3)

# Create production company comparison matrix and heatmap
company_matrix = compare_clusters_by_attribute(cluster_companies)
df_company_heatmap = create_attribute_heatmap(company_matrix, analysis_type='production_company', top_n_clusters=len(cluster_movies), top_n_items=40)
# Out:
# Visualization saved as 'cluster_production_company_distribution.png'
# Production Company Specialization ranking
#
# Most Specialized (focused on fewer production companies):
#  1. Cluster 22: Diversity=0.000, Unique=1, Total mentions=2
#       → Top production companies: Abraxas Film (100.0%)
#  2. Cluster 26: Diversity=0.000, Unique=1, Total mentions=2
#       → Top production companies: Fulwell 73 (100.0%)
#  3. Cluster 27: Diversity=0.000, Unique=1, Total mentions=3
#       → Top production companies: Collingwood Management (100.0%)
#  4. Cluster 28: Diversity=0.000, Unique=1, Total mentions=2
#       → Top production companies: Jaffa Films (II) (100.0%)
#  5. Cluster 29: Diversity=0.000, Unique=1, Total mentions=1
#       → Top production companies: William Winckler Productions (100.0%)
#  6. Cluster 14: Diversity=0.503, Unique=22, Total mentions=277
#       → Top production companies: A Bunch of Filmmakers (63.5%), Vestra Pictures (8.7%), Body Bag Films (7.9%)
#  7. Cluster 19: Diversity=0.599, Unique=10, Total mentions=117
#       → Top production companies: Dutchess Music (61.5%), EuropaCorp (12.0%), Foxy Films (7.7%)
#  8. Cluster 16: Diversity=0.695, Unique=38, Total mentions=331
#       → Top production companies: Black Toffee / SnapperPunchFish (29.0%), High Performance Films LLC (21.8%), Fun Size Horror Productions (10.6%)
#  9. Cluster 12: Diversity=0.832, Unique=123, Total mentions=1115
#       → Top production companies: Elysium Bandini Studios (18.3%), Columbia Pictures (7.3%), RabbitBandini Productions (5.8%)
# 10. Cluster  1: Diversity=0.841, Unique=1588, Total mentions=22815
#       → Top production companies: Columbia Pictures (5.2%), Universal Pictures (4.7%), New Line Cinema (3.1%)
#
# Most Diverse (spread across many production companies):
#  1. Cluster 25: Diversity=1.000, Unique=2, Total mentions=2
#       → Top production companies: Kruthuset AB (50.0%), ElSobky Film (50.0%)
#  2. Cluster 24: Diversity=1.000, Unique=2, Total mentions=2
#       → Top production companies: Jost Hering Filmproduktion (50.0%), Kineo Filmproduktion (50.0%)
#  3. Cluster 20: Diversity=1.000, Unique=8, Total mentions=8
#       → Top production companies: Budapest Filmstúdió (12.5%), Eurofilm Stúdió (12.5%), Hunnia Filmstúdió (12.5%)
#  4. Cluster 21: Diversity=0.974, Unique=8, Total mentions=10
#       → Top production companies: AM Pictures (20.0%), NL Film (20.0%), Aydin Film (10.0%)
#  5. Cluster 17: Diversity=0.947, Unique=43, Total mentions=174
#       → Top production companies: Mystery Productions (5.7%), Skyline Pictures (II) (5.7%), Polsky Films (5.7%)
#  6. Cluster 18: Diversity=0.938, Unique=21, Total mentions=36
#       → Top production companies: TAFF Pictures (13.9%), FBR Productions (11.1%), Ay Yapim (8.3%)
#  7. Cluster  8: Diversity=0.929, Unique=428, Total mentions=925
#       → Top production companies: Dharma Productions (3.4%), Eros International (2.9%), Mukta Arts (2.1%)
#  8. Cluster  0: Diversity=0.922, Unique=2744, Total mentions=14564
#       → Top production companies: Dimension Films (1.8%), Epic Pictures Group (1.4%), New Line Cinema (0.9%)
#  9. Cluster 23: Diversity=0.918, Unique=2, Total mentions=3
#       → Top production companies: HI-AX (66.7%), Studio Saboteur (33.3%)
# 10. Cluster 10: Diversity=0.904, Unique=308, Total mentions=1231
#       → Top production companies: Zentropa Entertainments (3.7%), Nimbus Film Productions (3.1%), Film i Väst (2.8%)
# Heatmap saved as 'production_company_heatmap.png'

# %% [markdown]
# Time Era analysis

# %%
from Actor_Director_Graph.cluster_time_period_analysis import (
    analyze_cluster_time_periods,
    categorize_by_era,
    print_time_period_summary,
    find_era_specialized_clusters,
    visualize_era_distribution,
    create_timeline_heatmap
)

# %%
# Analyze time period statistics for each cluster
df_time_stats = analyze_cluster_time_periods(cluster_unique_movies, cluster_to_nodes)

# Categorize movies by era (Classic, Golden Age, Modern, Contemporary)
df_era = categorize_by_era(cluster_unique_movies, cluster_to_nodes)

# %%
# Print comprehensive time period summary
print_time_period_summary(df_time_stats, df_era, top_n=20)
# Out:
# TIme period analysis by cluster:
#
# Cluster  Movies   Members  Year Range      Mean Year    Median   Dominant Era
# ----------------------------------------------------------------------------------------------------
# 0        4092     5525     1990-2021       2008.4       2010     Modern
# 2        3278     3784     1990-2021       2005.3       2006     Classic
# 4        2848     2338     1990-2021       2008.5       2010     Modern
# 1        2761     4321     1990-2021       2009.2       2010     Modern
# 3        2665     3497     1990-2021       2008.2       2010     Modern
# 5        786      1085     1990-2021       2008.1       2009     Modern
# 8        734      693      1990-2021       2009.1       2010     Modern
# 10       611      521      1990-2021       2008.8       2009     Modern
# 7        485      705      1991-2021       2012.9       2014     Modern
# 6        460      781      1990-2021       2011.3       2014     Contemporary
# 11       389      346      1990-2021       2004.8       2005     Classic
# 13       277      274      1992-2020       2010.7       2012     Modern
# 9        272      547      1990-2021       2011.3       2012     Modern
# 12       161      311      1990-2021       2010.3       2013     Modern
# 15       74       134      1991-2020       2011.5       2013     Modern
# 17       50       86       1991-2020       2010.6       2012     Modern
# 16       46       130      1995-2020       2013.7       2015     Contemporary
# 18       38       39       2004-2020       2013.5       2014     Modern
# 14       36       154      2005-2020       2016.3       2017     Contemporary
# 19       11       33       1990-2018       2007.2       2007     Golden Age
#
# ================================================================================
# Era distribution by cluster
# ================================================================================
#
# Era Definitions:
#   - Classic: Before 1970
#   - Golden Age: 1970-1989
#   - Modern: 1990-2009
#   - Contemporary: 2010-2021
#
#
# Cluster  Movies   Classic      Golden       Modern       Contemporary
# --------------------------------------------------------------------------------
# 0        4092      808 (19.7%)   841 (20.6%)  1390 (34.0%)  1053 (25.7%)
# 2        3278      996 (30.4%)   840 (25.6%)   922 (28.1%)   520 (15.9%)
# 4        2848      430 (15.1%)   731 (25.7%)  1047 (36.8%)   640 (22.5%)
# 1        2761      404 (14.6%)   641 (23.2%)   987 (35.7%)   729 (26.4%)
# 3        2665      501 (18.8%)   624 (23.4%)   915 (34.3%)   625 (23.5%)
# 5        786       143 (18.2%)   195 (24.8%)   274 (34.9%)   174 (22.1%)
# 8        734       107 (14.6%)   169 (23.0%)   275 (37.5%)   183 (24.9%)
# 10       611        74 (12.1%)   172 (28.2%)   238 (39.0%)   127 (20.8%)
# 7        485        18 ( 3.7%)    58 (12.0%)   226 (46.6%)   183 (37.7%)
# 6        460        49 (10.7%)    66 (14.3%)   167 (36.3%)   178 (38.7%)
# 11       389       128 (32.9%)    93 (23.9%)   114 (29.3%)    54 (13.9%)
# 13       277         8 ( 2.9%)    74 (26.7%)   125 (45.1%)    70 (25.3%)
# 9        272        18 ( 6.6%)    53 (19.5%)   112 (41.2%)    89 (32.7%)
# 12       161        23 (14.3%)    27 (16.8%)    63 (39.1%)    48 (29.8%)
# 15       74          6 ( 8.1%)    14 (18.9%)    31 (41.9%)    23 (31.1%)
# 17       50          6 (12.0%)     7 (14.0%)    23 (46.0%)    14 (28.0%)
# 16       46          1 ( 2.2%)     5 (10.9%)    19 (41.3%)    21 (45.7%)
# 18       38          0 ( 0.0%)     5 (13.2%)    19 (50.0%)    14 (36.8%)
# 14       36          0 ( 0.0%)     1 ( 2.8%)    10 (27.8%)    25 (69.4%)
# 19       11          2 (18.2%)     4 (36.4%)     2 (18.2%)     3 (27.3%)

# %%
# Find clusters that are specialized in specific eras (>60% of movies in one era)
specialized_clusters = find_era_specialized_clusters(df_era, threshold=60)
# Out:
# Clusters specialized in specific eras(>60% in one era)
#
# Cluster    Era                            Movies          Percentage
# ----------------------------------------------------------------------
# 22         Contemporary (2016-2021)       3/3          100.0       %
# 23         Contemporary (2016-2021)       2/2          100.0       %
# 24         Contemporary (2016-2021)       3/3          100.0       %
# 25         Contemporary (2016-2021)       2/2          100.0       %
# 26         Contemporary (2016-2021)       2/2          100.0       %
# 27         Modern (2008-2016)             1/1          100.0       %
# 28         Contemporary (2016-2021)       1/1          100.0       %
# 29         Golden Age (2000-2008)         1/1          100.0       %
# 14         Contemporary (2016-2021)       25/36         69.4        %

# %%
# Create era distribution visualization (stacked bar chart)
fig_era = visualize_era_distribution(df_era, output_file='cluster_era_distribution.png', top_n=20)
# Out:
# Visualization saved as 'cluster_era_distribution.png'

# %%
# Create timeline heatmap showing movie distribution by decade
fig_timeline = create_timeline_heatmap(cluster_unique_movies, output_file='cluster_timeline_heatmap.png', top_n=20)
# Out:
# Timeline heatmap saved as 'cluster_timeline_heatmap.png'

# %% [markdown]
# ## Sentiment Analysis on Movies of Popular Actors
#
# In this section, we analyze the sentiment of movie descriptions for films featuring popular actors from the Celebrity.csv dataset. We try to find out whether popular actors has a specific sentiment of movies

# %%
# Load celebrity data if not already loaded
if 'df_celebrity' not in globals():
    df_celebrity = pd.read_csv('../Datasets/Celebrity.csv', index_col=0)

# Load IMDb movies data if not already loaded  
if 'df_movies_imdb' not in globals():
    df_movies_imdb = pd.read_csv('../Datasets/IMDb movies.csv', index_col=0, low_memory=False)

# Load actor films data if not already loaded
if 'df_actors' not in globals():
    df_actors = pd.read_csv('../Datasets/IMDB/actorfilms.csv', low_memory=False)
    df_actors = df_actors[pd.to_numeric(df_actors['Year'], errors='coerce') >= 1980]

# %%
# Select top celebrities for analysis (top 50 by popularity)
top_celebrities = df_celebrity.nlargest(500, 'popularity')
print(f"Analyzing top {len(top_celebrities)} celebrities by popularity")

celebrity_names = top_celebrities['name'].tolist()
actor_movies = df_actors[df_actors['Actor'].isin(celebrity_names)].copy()

print(f"Found {len(actor_movies)} movie entries for top celebrities")


df_movies_imdb_clean = df_movies_imdb[['title', 'description', 'avg_vote', 'year']].copy()
df_movies_imdb_clean = df_movies_imdb_clean.dropna(subset=['description'])

# Merge actor movies with movie descriptions
actor_movies_with_desc = actor_movies.merge(
    df_movies_imdb_clean,
    left_on='Film',
    right_on='title',
    how='inner'
)

print(f"Matched {len(actor_movies_with_desc)} movies with descriptions")
print(f"Unique movies: {actor_movies_with_desc['Film'].nunique()}")
actor_movies_with_desc.head()
# Out:
# Analyzing top 500 celebrities by popularity
# Found 11977 movie entries for top celebrities
# Matched 6688 movies with descriptions
# Unique movies: 3512
#        Actor    ActorID         Film  Year   Votes  Rating     FilmID  \
# 0  Brad Pitt  nm0000093     Ad Astra  2019  202998     6.5  tt2935510
# 1  Brad Pitt  nm0000093   Deadpool 2  2018  489623     7.7  tt5463162
# 2  Brad Pitt  nm0000093  War Machine  2017   42444     6.0  tt4758646
# 3  Brad Pitt  nm0000093   By the Sea  2015   18967     5.3  tt3707106
# 4  Brad Pitt  nm0000093         Fury  2014  432374     7.6  tt2713180
#
#          title                                        description  avg_vote  \
# 0     Ad Astra  Astronaut Roy McBride undertakes a mission acr...       6.6
# 1   Deadpool 2  Foul-mouthed mutant mercenary Wade Wilson (a.k...       7.7
# 2  War Machine  An idiosyncratic general confronts opposition ...       6.0
# 3   By the Sea  A couple tries to repair their marriage while ...       5.3
# 4         Fury  After twenty years in prison, Foley is finishe...       5.6
#
#    year
# 0  2019
# 1  2018
# 2  2017
# 3  2015
# 4  2012

# %%
from Actor_Director_Graph.sentiment_analysis import calculate_sentiment

unique_movies = actor_movies_with_desc[['Film', 'description']].drop_duplicates(subset=['Film'])
print(f"Analyzing sentiment for {len(unique_movies)} unique movies")

descriptions = unique_movies['description'].tolist()
sentiment_results = calculate_sentiment(descriptions, batch_size=16)

# Add sentiment results to unique movies
unique_movies['sentiment_label'] = [r['label'] if r else None for r in sentiment_results]
unique_movies['sentiment_score'] = [r['score'] if r else None for r in sentiment_results]

unique_movies['sentiment_value'] = unique_movies.apply(
    lambda row: row['sentiment_score'] if row['sentiment_label'] == 'POSITIVE' else -row['sentiment_score'] if row['sentiment_label'] == 'NEGATIVE' else 0,
    axis=1
)

print(f"\nSentiment distribution:")
print(unique_movies['sentiment_label'].value_counts())
print(f"\nAverage sentiment score: {unique_movies['sentiment_value'].mean():.3f}")
unique_movies.head(10)
# Out:
# Analyzing sentiment for 3512 unique movies
# 100%|██████████| 220/220 [00:54<00:00,  4.07it/s]
# Sentiment distribution:
# sentiment_label
# POSITIVE    1899
# NEGATIVE    1613
# Name: count, dtype: int64
#
# Average sentiment score: 0.082
#                 Film                                        description  \
# 0           Ad Astra  Astronaut Roy McBride undertakes a mission acr...
# 1         Deadpool 2  Foul-mouthed mutant mercenary Wade Wilson (a.k...
# 2        War Machine  An idiosyncratic general confronts opposition ...
# 3         By the Sea  A couple tries to repair their marriage while ...
# 4               Fury  After twenty years in prison, Foley is finishe...
# 6        World War Z  Former United Nations employee Gerry Lane trav...
# 7   The Tree of Life  The story of a family in Waco, Texas in 1956. ...
# 8           Megamind  The supervillain Megamind finally defeats his ...
# 9   Ocean's Thirteen  Danny Ocean rounds up the boys for a third hei...
# 10             Babel  Babel tells the story of the Babels, a strange...
#
#    sentiment_label  sentiment_score  sentiment_value
# 0         POSITIVE         0.978466         0.978466
# 1         NEGATIVE         0.665035        -0.665035
# 2         POSITIVE         0.998535         0.998535
# 3         NEGATIVE         0.996944        -0.996944
# 4         POSITIVE         0.763204         0.763204
# 6         POSITIVE         0.831820         0.831820
# 7         POSITIVE         0.982657         0.982657
# 8         NEGATIVE         0.999605        -0.999605
# 9         NEGATIVE         0.519983        -0.519983
# 10        POSITIVE         0.996944         0.996944

# %%
actor_movies_sentiment = actor_movies_with_desc.merge(
    unique_movies[['Film', 'sentiment_label', 'sentiment_score', 'sentiment_value']],
    on='Film',
    how='left'
)

# Calculate average sentiment per actor
actor_sentiment_stats = actor_movies_sentiment.groupby('Actor').agg({
    'sentiment_value': ['mean', 'median', 'std', 'count'],
    'sentiment_label': lambda x: (x == 'POSITIVE').sum() / len(x) if len(x) > 0 else 0
}).round(3)

all_actor_sentiment_stats = actor_movies_sentiment.groupby('Actor').agg({
    'sentiment_value': ['mean', 'median', 'std', 'count'],
    'sentiment_label': lambda x: (x == 'POSITIVE').sum() / len(x) if len(x) > 0 else 0
}).round(3)

actor_sentiment_stats.columns = ['avg_sentiment', 'median_sentiment', 'std_sentiment', 'num_movies', 'positive_ratio']
actor_sentiment_stats = actor_sentiment_stats[actor_sentiment_stats['num_movies'] >= 3]  # Filter actors with at least 3 movies

all_actor_sentiment_stats.columns = ['avg_sentiment', 'median_sentiment', 'std_sentiment', 'num_movies', 'positive_ratio']
all_actor_sentiment_stats = actor_sentiment_stats[actor_sentiment_stats['num_movies'] >= 3]  # Filter actors with at least 3 movies

# Merge with celebrity data to get popularity
actor_sentiment_stats = actor_sentiment_stats.merge(
    top_celebrities[['name', 'popularity']],
    left_index=True,
    right_on='name',
    how='inner'
)

all_actor_sentiment_stats = all_actor_sentiment_stats.merge(
    top_celebrities[['name', 'popularity']],
    left_index=True,
    right_on='name',
    how='inner'
)

# %%
top_20_actors = actor_sentiment_stats.nlargest(20, 'avg_sentiment')

plt.figure(figsize=(12, 8))
bars = plt.barh(range(len(top_20_actors)), top_20_actors['avg_sentiment'])


colors = ['green' if x > 0 else 'red' for x in top_20_actors['avg_sentiment']]
for bar, color in zip(bars, colors):
    bar.set_color(color)
    bar.set_alpha(0.7)

plt.yticks(range(len(top_20_actors)), top_20_actors['name'])
plt.xlabel('Average Sentiment Score')
plt.title('Top 20 Actors by Average Movie Sentiment Score')
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.5)
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()

# %%
from scipy import stats

plt.figure(figsize=(12, 8))

scatter = plt.scatter(
    actor_sentiment_stats['popularity'],
    actor_sentiment_stats['avg_sentiment'],
    s=actor_sentiment_stats['num_movies'] * 10,
    alpha=0.6,
    c=actor_sentiment_stats['positive_ratio'],
    cmap='RdYlGn'
)

plt.xlabel('Actor Popularity')
plt.ylabel('Average Sentiment Score')
plt.title('Actor popularity and their average film sentiment\n(Size = Number of Movies, Color = Sentiment score)')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5, alpha=0.5)
plt.grid(True, alpha=0.3)


cbar = plt.colorbar(scatter)
cbar.set_label('Positive Movie Ratio')

top_popular = actor_sentiment_stats.nlargest(15, 'popularity')
for _, actor in top_popular.iterrows():
    plt.annotate(
        actor['name'],
        (actor['popularity'], actor['avg_sentiment']),
        fontsize=8,
        alpha=0.7,
        xytext=(5, 5),
        textcoords='offset points'
    )

top_sentiment = actor_sentiment_stats.nlargest(10, 'avg_sentiment')
for _, actor in top_sentiment.iterrows():
    if actor['name'] not in top_popular['name'].values:
        plt.annotate(
            actor['name'],
            (actor['popularity'], actor['avg_sentiment']),
            fontsize=8,
            alpha=0.7,
            xytext=(5, 5),
            textcoords='offset points'
        )

# Annotate actors with lowest sentiment scores
bottom_sentiment = actor_sentiment_stats.nsmallest(10, 'avg_sentiment')
for _, actor in bottom_sentiment.iterrows():
    if actor['name'] not in top_popular['name'].values:
        plt.annotate(
            actor['name'],
            (actor['popularity'], actor['avg_sentiment']),
            fontsize=8,
            alpha=0.7,
            xytext=(5, -10),
            textcoords='offset points'
        )


most_movies = actor_sentiment_stats.nlargest(10, 'num_movies')
for _, actor in most_movies.iterrows():
    already_labeled = (actor['name'] in top_popular['name'].values or
                       actor['name'] in top_sentiment['name'].values or
                       actor['name'] in bottom_sentiment['name'].values)
    if not already_labeled:
        plt.annotate(
            actor['name'],
            (actor['popularity'], actor['avg_sentiment']),
            fontsize=8,
            alpha=0.7,
            xytext=(-5, -10),
            textcoords='offset points'
        )

plt.tight_layout()
plt.savefig('actor_popularity_and_the_average_sentiment_score_of_their_films.png', dpi=300, bbox_inches='tight')
plt.show()


spearman_corr, p_value = stats.spearmanr(actor_sentiment_stats['popularity'], actor_sentiment_stats['avg_sentiment'])
print(f"\nSpearman correlation between popularity and average sentiment: {spearman_corr:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Spearman correlation between popularity and average sentiment: -0.098
# P-value: 0.0668

# %%
spearman_corr, p_value = stats.spearmanr(all_actor_sentiment_stats['popularity'], all_actor_sentiment_stats['avg_sentiment'])
print(f"\nSpearman correlation between popularity and average sentiment: {spearman_corr:.3f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Spearman correlation between popularity and average sentiment: -0.098
# P-value: 0.0668
